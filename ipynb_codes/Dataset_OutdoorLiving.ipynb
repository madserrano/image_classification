# %% [markdown]
# # Datasets for Outdoor Living section

# %% [markdown]
# <b>Capstone Project:</b> Product Recognition for Canadian Tire

# %% [markdown]
# ## OUTDOOR FURNITURE

# %%
# Importing required libraries
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/outdoor-living/patio-furniture/dining.html?adlocation=LIT_PatioDiningFurniture_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/patio-furniture/lounge-furniture.html?adlocation=LIT_PatioLoungeFurniture_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/gazebos-pergolas-canopies.html?adlocation=LIT_GazebosPergolasCanopies_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/patio-furniture/tables.html?adlocation=LIT_PatioTables_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/patio-furniture/patio-seating.html?adlocation=LIT_PatioSeating_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/patio-furniture/hammocks-swings.html?adlocation=LIT_HammocksPatioSwings_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/patio-furniture/small-space-furniture.html?adlocation=LIT_SmallSpaceFurniture_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/dining-entertaining.html?adlocation=LIT_OutdoorDiningEntertaining_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-heating.html?adlocation=LIT_Patioheaters_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/patio-furniture/patio-cushions.html?adlocation=LIT_PatioCushionsSeatPads_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/patio-furniture/outdoor-rugs.html?adlocation=LIT_OutdoorRugsFlooring_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-lighting.html?adlocation=LIT_OutdoorLighting_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/garden-decor/outdoor-decor-accessories.html?adlocation=LIT_PatioDecorAccessories_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/garden-care/pots-planters.html?adlocation=LIT_PotsPlanters_PartioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/mosquito-insect-pest-control/bug-zappers-mosquito-repellents.html?adlocation=LIT_BugZappersMosquitoRepellents_PartioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/patio-furniture/umbrellas-bases/umbrellas.html?adlocation=LIT_PatioUmbrellas_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/patio-furniture/umbrellas-bases/umbrella-bases.html?adlocation=LIT_PatioUmbrellaBases_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/patio-furniture/furniture-covers-accessories.html?adlocation=LIT_PatioFurnitureCoversAccessories_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/sheds-storage.html?adlocation=LIT_DeckBoxesOutdoorStorage_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/pdp/0882273.html?adlocation=LIT_BaffinSectionalSet_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/pdp/0882266.html?adlocation=LIT_RockcliffeCasualDiningSet_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/pdp/0882263.html?adlocation=LIT_RosedaleConversationSet_PatioFurnitureCLP_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/patio-furniture/lounge-conversation-sets/canvas-breton-conversation-collection.html?adlocation=LIT_BretonConversationDiningCollection_PatioFurnitureCLP_en;'
                 
                ]

product_link_name = ['PATIO DINING FURNITURE',
                     'PATIO LOUNGE FURNITURE',
                     'GAZEBOS PERGOLAS AND CANOPIES',
                     'PATIO TABLES',
                     'PATIO SEATING',
                     'HAMMOCKS AND PATIO SWINGS',
                     'SMALL SPACE FURNITURE',
                     'OUTDOOR DINING AND ENTERTAINING',
                     'OUTDOOR HEATING',
                     'PATIO CUSHIONS AND SEAT PADS',
                     'OUTDOOR RUGS AND FLOORING',
                     'OUTDOOR LIGHTING',
                     'OUTDOOR DECOR ACCESSORIES',
                     'POTS AND PLANTERS',
                     'BUG ZAPPERS AND MOSQUITO REPELLENTS',
                     'PATIO UMBRELLAS',
                     'PATIO UMBRELLA BASES',
                     'PATIO FURNITURE COVERS AND ACCESSORIES',
                     'DECK BOXES AND OUTDOOR STORAGE',
                     'BAFFIN SECTIONAL SET',
                     'ROCKCLIFFE CASUAL DINING SET',
                     'ROSEDALE CONVERSATION SET',
                     'CANVAS BRETON CONVERSATION COLLECTION'                   
        ]

### FILL THIS OUT######
product = "OUTDOOR_FURNITURE"
maj_name = "OUTDOOR FURNITURE"
maj_link = "https://www.canadiantire.ca/en/outdoor-living/patio-furniture.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#         product_name              product_link_name  \
# 0  OUTDOOR_FURNITURE         PATIO DINING FURNITURE
# 1  OUTDOOR_FURNITURE         PATIO LOUNGE FURNITURE
# 2  OUTDOOR_FURNITURE  GAZEBOS PERGOLAS AND CANOPIES
# 3  OUTDOOR_FURNITURE                   PATIO TABLES
# 4  OUTDOOR_FURNITURE                  PATIO SEATING
#
#                                                 link major_category_name  \
# 0  https://www.canadiantire.ca/en/outdoor-living/...   OUTDOOR FURNITURE
# 1  https://www.canadiantire.ca/en/outdoor-living/...   OUTDOOR FURNITURE
# 2  https://www.canadiantire.ca/en/outdoor-living/...   OUTDOOR FURNITURE
# 3  https://www.canadiantire.ca/en/outdoor-living/...   OUTDOOR FURNITURE
# 4  https://www.canadiantire.ca/en/outdoor-living/...   OUTDOOR FURNITURE
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/outdoor-living/...
# 1  https://www.canadiantire.ca/en/outdoor-living/...
# ...

# %% [markdown]
# ## BBQ SMOKERS AND ACCESSORIES

# %%
# Importing required libraries
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/content/canadian-tire/en/outdoor-living/bbqs-smokers-accessories/bbq-trends.html?adlocation=LIT_BBQTrends2021_BBQSmokersAccessoriesCLP_en;',
                 'https://www.canadiantire.ca/content/canadian-tire/en/outdoor-living/bbqs-smokers-accessories/bbqs/gas-bbqs.html?adlocation=LIT_GasBBQ_BBQSmokersAccessoriesCLP_en;',
                 'https://www.canadiantire.ca/content/canadian-tire/en/outdoor-living/bbqs-smokers-accessories/bbqs/portable-bbqs.html?adlocation=LIT_PortableBBQ_BBQSmokersAccessoriesCLP_en;',
                 'https://www.canadiantire.ca/content/canadian-tire/en/outdoor-living/bbqs-smokers-accessories/bbqs/charcoal-bbqs.html?adlocation=LIT_CharcoalGrills_BBQSmokersAccessoriesCLP_en;',
                 'https://www.canadiantire.ca/content/canadian-tire/en/outdoor-living/bbqs-smokers-accessories/bbqs/electric-bbqs.html?adlocation=LIT_ElectricBBQ_BBQSmokersAccessoriesCLP_en;',
                 'https://www.canadiantire.ca/content/canadian-tire/en/outdoor-living/bbqs-smokers-accessories/smokers-accessories.html?adlocation=LIT_SmokersWoodPelletGrills_BBQSmokersAccessoriesCLP_en;',
                 'https://www.canadiantire.ca/content/canadian-tire/en/outdoor-living/bbqs-smokers-accessories/outdoor-cookers-fryers.html?adlocation=LIT_OutdoorCookersFryers_BBQSmokersAccessoriesCLP_en;',
                 'https://www.canadiantire.ca/content/canadian-tire/en/outdoor-living/bbqs-smokers-accessories/bbq-replacement-parts.html?adlocation=LIT_BBQReplacementParts_BBQSmokersAccessoriesCLP_en;',
                 'https://www.canadiantire.ca/content/canadian-tire/en/outdoor-living/bbqs-smokers-accessories/bbq-tools-cooking-accessories.html?adlocation=LIT_BBQToolsCookingAccessories_BBQSmokersAccessoriesCLP_en;',
                 'https://www.canadiantire.ca/content/canadian-tire/en/outdoor-living/bbqs-smokers-accessories/propane-tanks-charcoal.html?adlocation=LIT_PropaneTanksAndCharcoal_BBQSmokersAccessoriesCLP_en;',
                 'https://www.canadiantire.ca/content/canadian-tire/en/outdoor-living/bbqs-smokers-accessories/bbq-covers.html?adlocation=LIT_BBQCovers_BBQSmokersAccessoriesCLP_en;'
                ]

product_link_name = ['BBQ TRENDS 2021',
                     'GAS BBQS',
                     'PORTABLE BBQS',
                     'CHARCOAL BBQS',
                     'ELECTRIC BBQS',
                     'SMOKERS AND WOOD PELLET GRILLS',
                     'OUTDOOR COOKERS AND FRYERS',
                     'BBQ REPLACEMENT PARTS',
                     'BBQ TOOLS AND COOKING ACCESSORIES',
                     'PROPANE TANKS AND CHARCOAL',
                     'BBQ COVERS'                
        ]

### FILL THIS OUT######
product = "BBQ_SMOKERS_ACC"
maj_name = "BBQ SMOKERS AND ACCESSORIES"
maj_link = "https://www.canadiantire.ca/en/outdoor-living/bbqs-smokers-accessories.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#       product_name product_link_name  \
# 0  BBQ_SMOKERS_ACC   BBQ TRENDS 2021
# 1  BBQ_SMOKERS_ACC          GAS BBQS
# 2  BBQ_SMOKERS_ACC     PORTABLE BBQS
# 3  BBQ_SMOKERS_ACC     CHARCOAL BBQS
# 4  BBQ_SMOKERS_ACC     ELECTRIC BBQS
#
#                                                 link  \
# 0  https://www.canadiantire.ca/content/canadian-t...
# 1  https://www.canadiantire.ca/content/canadian-t...
# 2  https://www.canadiantire.ca/content/canadian-t...
# 3  https://www.canadiantire.ca/content/canadian-t...
# 4  https://www.canadiantire.ca/content/canadian-t...
#
#            major_category_name  \
# 0  BBQ SMOKERS AND ACCESSORIES
# 1  BBQ SMOKERS AND ACCESSORIES
# 2  BBQ SMOKERS AND ACCESSORIES
# 3  BBQ SMOKERS AND ACCESSORIES
# 4  BBQ SMOKERS AND ACCESSORIES
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/outdoor-living/...
# 1  https://www.canadiantire.ca/en/outdoor-living/...
# 2  https://www.canadiantire.ca/en/outdoor-living/...
# ...

# %%
# Importing required libraries
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/outdoor-living/outdoor-power-equipment/lawn-mowers.html?adlocation=LIT_Category_Product_LawnMowers_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-power-equipment/hedge-trimmers.html?adlocation=LIT_Category_Product_HedgeTrimmersCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-power-equipment/tillers-cultivators.html?adlocation=LIT_Category_Product_TillersAndCultivatorsCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-power-equipment/grass-trimmers.html?adlocation=LIT_Category_Product_GrassTrimmers_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/generators-accessories.html?adlocation=LIT_Category_Product_GeneratorsAccessoriesCat_en;',
                 'https://www.canadiantire.ca/en/automotive/pressure-washers-parts-accessories.html?adlocation=LIT_Category_Product_PressureWashers_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-power-equipment/leaf-blowers.html?adlocation=LIT_Category_Product_LeafBlowersCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-power-equipment/chainsaws.html?adlocation=LIT_Category_Product_ChainsawsCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-power-equipment/log-splitters-chippers-shredders.html?adlocation=LIT_Category_Product_LogSplittersChippersShreddersCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/snow-removal/snowblowers.html?adlocation=LIT_Category_Product_Snowblowers_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/electrical/extension-cords/outdoor-extension-cords.html?adlocation=LIT_Category_Product_OutdoorExtensionCordsCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/snow-removal/snowblower-parts-accessories.html?adlocation=LIT_Category_Product_SnowblowerAccessories_en;',                 
                 'https://www.canadiantire.ca/en/automotive/oils-fluids-additives-chemicals/fuel-system-additives-cleaners/fuel-stabilizers-small-engine-additives.html?adlocation=LIT_Category_Product_FuelStabilizersSmallEngineAdditives_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-power-equipment/small-engine-spark-plugs.html?adlocation=LIT_Category_Product_SmallEngineSparkPlugs_en;'
                ]

product_link_name = ['LAWN MOWERS',
                    'HEDGE TRIMMERS',
                    'TILLERS AND CULTIVATORS',
                    'GRASS TRIMMERS',
                    'GENERATORS AND ACCESSORIES',
                    'PRESSURE WASHERS, PARTS AND ACCESSORIES',
                    'LEAF BLOWERS AND ACCESSORIES',
                    'CHAINSAWS',
                    'LOG SPLITTERS, WOOD CHIPPERS AND SHREDDERS',
                    'SNOWBLOWERS',
                    'OUTDOOR EXTENSION CORDS',
                    'SNOWBLOWER ACCESSORIES',
                    'FUEL STABILIZERS AND SMALL ENGINE ADDITIVES',
                    'SMALL ENGINE SPARK PLUGS'                   
        ]

### FILL THIS OUT######
product = "OUTDOOR_POWER_EQUIPMENT"
maj_name = "OUTDOOR POWER EQUIPMENT"
maj_link = "https://www.canadiantire.ca/en/outdoor-living/outdoor-power-equipment.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#               product_name           product_link_name  \
# 0  OUTDOOR_POWER_EQUIPMENT                 LAWN MOWERS
# 1  OUTDOOR_POWER_EQUIPMENT              HEDGE TRIMMERS
# 2  OUTDOOR_POWER_EQUIPMENT     TILLERS AND CULTIVATORS
# 3  OUTDOOR_POWER_EQUIPMENT              GRASS TRIMMERS
# 4  OUTDOOR_POWER_EQUIPMENT  GENERATORS AND ACCESSORIES
#
#                                                 link      major_category_name  \
# 0  https://www.canadiantire.ca/en/outdoor-living/...  OUTDOOR POWER EQUIPMENT
# 1  https://www.canadiantire.ca/en/outdoor-living/...  OUTDOOR POWER EQUIPMENT
# 2  https://www.canadiantire.ca/en/outdoor-living/...  OUTDOOR POWER EQUIPMENT
# 3  https://www.canadiantire.ca/en/outdoor-living/...  OUTDOOR POWER EQUIPMENT
# 4  https://www.canadiantire.ca/en/tools-hardware/...  OUTDOOR POWER EQUIPMENT
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/outdoor-living/...
# 1  https://www.canadiantire.ca/en/outdoor-living/...
# ...

# %% [markdown]
# ## WATERING AND IRRIGATION

# %%
# Importing required libraries
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/watering-irrigation/garden-hoses.html?adlocation=LIT_Category_Product_GardenHosesCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/watering-irrigation/hose-reels-storage.html?adlocation=LIT_Category_Product_HoseReelsStorageCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/watering-irrigation/hose-accessories.html?adlocation=LIT_Category_Product_HoseAccessoriesCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/watering-irrigation/lawn-sprinklers.html?adlocation=LIT_Category_Product_LawnSprinklersCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/watering-irrigation/rain-barrels.html?adlocation=LIT_Category_Product_RainBarrelsCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/watering-irrigation/water-timers.html?adlocation=LIT_Category_Product_WaterTimersCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/watering-irrigation/hose-nozzles-wands.html?adlocation=LIT_Category_Product_HoseNozzlesWandsCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/watering-irrigation/watering-cans.html?adlocation=LIT_Category_Product_WateringCansCat_en;'
                ]

product_link_name = ['GARDEN HOSES',
                     'HOSE REELS AND STORAGE',
                     'HOSE ACCESSORIES',
                     'SPRINKLERS',
                     'RAIN BARRELS',
                     'WATER TIMERS',
                     'HOSE NOZZLES AND WANDS',
                     'WATERING CANS'                    
        ]

### FILL THIS OUT######
product = "WATERING_IRRIGATION"
maj_name = "WATERING AND IRRIGATION"
maj_link = 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/watering-irrigation.html'
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#           product_name       product_link_name  \
# 0  WATERING_IRRIGATION            GARDEN HOSES
# 1  WATERING_IRRIGATION  HOSE REELS AND STORAGE
# 2  WATERING_IRRIGATION        HOSE ACCESSORIES
# 3  WATERING_IRRIGATION              SPRINKLERS
# 4  WATERING_IRRIGATION            RAIN BARRELS
#
#                                                 link      major_category_name  \
# 0  https://www.canadiantire.ca/en/outdoor-living/...  WATERING AND IRRIGATION
# 1  https://www.canadiantire.ca/en/outdoor-living/...  WATERING AND IRRIGATION
# 2  https://www.canadiantire.ca/en/outdoor-living/...  WATERING AND IRRIGATION
# 3  https://www.canadiantire.ca/en/outdoor-living/...  WATERING AND IRRIGATION
# 4  https://www.canadiantire.ca/en/outdoor-living/...  WATERING AND IRRIGATION
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/outdoor-living/...
# 1  https://www.canadiantire.ca/en/outdoor-living/...
# ...

# %% [markdown]
# ## LAWN AND PLANT CARE

# %%
# Importing required libraries
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/lawn-care/grass-seed.html?adlocation=LIT_LAWN-GARDEN-CENTER_GRASS-SEEDS_EN;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/garden-care/soils-mixes.html?adlocation=LIT_LAWN-GARDEN-CENTER_SOIL_EN;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/lawn-care/lawn-fertilizer.html?adlocation=LIT_LAWN-GARDEN-CENTER_LAWN-FERTILIZERS_EN',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/lawn-care/lawn-spreaders.html?adlocation=LIT_LAWN-GARDEN-CENTER_LAWN-SPREADERS_EN;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/hydroponics.html?adlocation=LIT_LAWN-GARDEN-CENTER_HYDROPONICS_EN;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/garden-care/pots-planters.html?adlocation=LIT_LAWN-GARDEN-CENTER_POTS-PLANTERS_EN;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/garden-care/plant-garden-fertilizers.html?adlocation=LIT_LAWN-GARDEN-CENTER_GRASS-SEEDS_EN;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/greenhouses.html?adlocation=LIT_LAWN-GARDEN-CENTER_GREENHOUSES_EN;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/landscaping.html?adlocation=LIT_LAWN-GARDEN-CENTER_LANDSCAPING_EN;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/garden-decor.html?adlocation=LIT_LAWN-GARDEN-CENTER_GARDEN-DECOR_EN;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/lawn-garden-tools.html?adlocation=LIT_LAWN-GARDEN-CENTER_LAWN-GARDEN-TOOLS_EN;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/garden-care.html?adlocation=LIT_LAWN-GARDEN-CENTER_GARDEN-CARE_EN;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/mosquito-insect-pest-control.html?adlocation=LIT_LAWN-GARDEN-CENTER_MOSQUITO-INSECT-PEST-CONTROL_EN;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/garden-care/bulbs-seeds-accessories.html?adlocation=LIT_LAWN-GARDEN-CENTER_BULBSSEEDS_EN;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/wheelbarrows-carts.html?adlocation=LIT_LAWN-GARDEN-CENTER_WHEELBARROWS-CARTS_EN;',
                 'https://www.canadiantire.ca/en/household-pets/cleaning-supplies-vacuums/garbage-cans-bags/compost-bins-bags.html?adlocation=LIT_LAWN-GARDEN-CENTER_COMPOSTING-RECYCLING_EN;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/watering-irrigation/garden-hoses.html?adlocation=LIT_LAWN-GARDEN-CENTER_GARDEN-HOSES_EN;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/watering-irrigation/lawn-sprinklers.html?adlocation=LIT_LAWN-GARDEN-CENTER_SPRINKLERS_EN;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/watering-irrigation/hose-reels-storage.html?adlocation=LIT_LAWN-GARDEN-CENTER_HOSE-REELS-STORAGE_EN;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/watering-irrigation/hose-nozzles-wands.html?adlocation=LIT_LAWN-GARDEN-CENTER_HOSE-NOZZLES-WANDS_EN;'
                ]

product_link_name = ['GRASS SEED',
                     'SOIL',
                     'LAWN FERTILIZERS',
                     'LAWN SPREADERS',
                     'HYDROPONICS',
                     'POTS AND PLANTERS',
                     'PLANT FOOD',
                     'GREENHOUSES',
                     'LANDSCAPING',
                     'GARDEN DÉCOR',
                     'LAWN AND GARDEN TOOLS',
                     'GARDEN CARE',
                     'MOSQUITO, INSECT AND PEST CONTROL',
                     'BULBS AND SEEDS',
                     'WHEELBARROWS AND CARTS',
                     'COMPOST BINS AND BAGS',
                     'GARDEN HOSES',
                     'LAWN SPRINKLERS',
                     'HOSE REELS AND STORAGE',
                     'HOSE NOZZLES AND WANDS'                    
        ]

### FILL THIS OUT######
product = "LAWN_PLANT_CARE"
maj_name = "LAWN AND PLANT CARE"
maj_link = "https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#       product_name product_link_name  \
# 0  LAWN_PLANT_CARE        GRASS SEED
# 1  LAWN_PLANT_CARE              SOIL
# 2  LAWN_PLANT_CARE  LAWN FERTILIZERS
# 3  LAWN_PLANT_CARE    LAWN SPREADERS
# 4  LAWN_PLANT_CARE       HYDROPONICS
#
#                                                 link  major_category_name  \
# 0  https://www.canadiantire.ca/en/outdoor-living/...  LAWN AND PLANT CARE
# 1  https://www.canadiantire.ca/en/outdoor-living/...  LAWN AND PLANT CARE
# 2  https://www.canadiantire.ca/en/outdoor-living/...  LAWN AND PLANT CARE
# 3  https://www.canadiantire.ca/en/outdoor-living/...  LAWN AND PLANT CARE
# 4  https://www.canadiantire.ca/en/outdoor-living/...  LAWN AND PLANT CARE
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/outdoor-living/...
# 1  https://www.canadiantire.ca/en/outdoor-living/...
# 2  https://www.canadiantire.ca/en/outdoor-living/...
# 3  https://www.canadiantire.ca/en/outdoor-living/...
# ...

# %% [markdown]
# ## MOSQUITO INSECT AND PEST CONTROL

# %%
# Importing required libraries
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/mosquito-insect-pest-control/ant-spider-crawling-insect-control.html?adlocation=LIT_Category_Product_AntsSpidersCrawlingControllCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/mosquito-insect-pest-control/bug-zappers-mosquito-repellents.html?adlocation=LIT_Category_Product_BugZappersMosquitoRepellentsCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/mosquito-insect-pest-control/wasps-hornets-control.html?adlocation=LIT_Category_Product_WaspsHornetsControllCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/mosquito-insect-pest-control/garden-insect-control.html?adlocation=LIT_Category_Product_PlantTreeInsectControllCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/mosquito-insect-pest-control/fly-traps-swatters.html?adlocation=LIT_Category_Product_FlyTrapsSwatterslCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/mosquito-insect-pest-control/bed-bugs-control.html?adlocation=LIT_Category_Product_BedBugsControl_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/mosquito-insect-pest-control/pest-rodent-control.html?adlocation=LIT_Category_Product_PestRodentControl_en;'
                ]

product_link_name = ['ANT SPIDER AND CRAWLING INSECT CONTROL',
                     'BUG ZAPPERS AND MOSQUITO REPELLENTS',
                     'WASPS AND HORNETS CONTROL',
                     'GARDEN INSECT CONTROL',
                     'FLY TRAPS AND SWATTERS',
                     'BED BUG CONTROL',
                     'PEST AND RODENT CONTROL'
                     
        ]

### FILL THIS OUT######
product = "MOSQUITO_INSECT_PESTCONTROL"
maj_name = "MOSQUITO INSECT AND PEST CONTROL"
maj_link = "https://www.canadiantire.ca/en/outdoor-living/lawn-garden-centre/mosquito-insect-pest-control.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#                   product_name                       product_link_name  \
# 0  MOSQUITO_INSECT_PESTCONTROL  ANT SPIDER AND CRAWLING INSECT CONTROL
# 1  MOSQUITO_INSECT_PESTCONTROL     BUG ZAPPERS AND MOSQUITO REPELLENTS
# 2  MOSQUITO_INSECT_PESTCONTROL               WASPS AND HORNETS CONTROL
# 3  MOSQUITO_INSECT_PESTCONTROL                   GARDEN INSECT CONTROL
# 4  MOSQUITO_INSECT_PESTCONTROL                  FLY TRAPS AND SWATTERS
#
#                                                 link  \
# 0  https://www.canadiantire.ca/en/outdoor-living/...
# 1  https://www.canadiantire.ca/en/outdoor-living/...
# 2  https://www.canadiantire.ca/en/outdoor-living/...
# 3  https://www.canadiantire.ca/en/outdoor-living/...
# 4  https://www.canadiantire.ca/en/outdoor-living/...
#
#                 major_category_name  \
# 0  MOSQUITO INSECT AND PEST CONTROL
# 1  MOSQUITO INSECT AND PEST CONTROL
# 2  MOSQUITO INSECT AND PEST CONTROL
# 3  MOSQUITO INSECT AND PEST CONTROL
# ...

# %% [markdown]
# ## OUTDOOR HEATING

# %%
# Importing required libraries
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/outdoor-living/outdoor-heating/firepits.html?adlocation=LIT_279X217_OutdoorLiving_Gazebos_Cat16777_Firepits_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-heating/fire-bowls.html?adlocation=LIT_279X217_OutdoorLiving_Gazebos_Cat16777_GasFireBowls_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-heating/fire-tables.html?adlocation=LIT_Category_Product_GasFireTablesCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-heating/fireplaces.html?adlocation=LIT_Category_Product_OutdoorFireplacesCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-heating/outdoor-heating-accessories.html?',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-heating/patio-heaters.html?adlocation=LIT_Category_Product_PatioHeatersCat_en;'
                ]

product_link_name = ['FIREPITS',
                     'FIRE BOWLS',
                     'FIRE TABLES',
                     'OUTDOOR FIREPLACES',
                     'OUTDOOR HEATING ACCESSORIES',
                     'PATIO HEATERS'                    
        ]

### FILL THIS OUT######
product = "OUTDOOR_HEATING"
maj_name = "OUTDOOR HEATING"
maj_link = "https://www.canadiantire.ca/en/outdoor-living/outdoor-heating.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#       product_name            product_link_name  \
# 0  OUTDOOR_HEATING                     FIREPITS
# 1  OUTDOOR_HEATING                   FIRE BOWLS
# 2  OUTDOOR_HEATING                  FIRE TABLES
# 3  OUTDOOR_HEATING           OUTDOOR FIREPLACES
# 4  OUTDOOR_HEATING  OUTDOOR HEATING ACCESSORIES
#
#                                                 link major_category_name  \
# 0  https://www.canadiantire.ca/en/outdoor-living/...     OUTDOOR HEATING
# 1  https://www.canadiantire.ca/en/outdoor-living/...     OUTDOOR HEATING
# 2  https://www.canadiantire.ca/en/outdoor-living/...     OUTDOOR HEATING
# 3  https://www.canadiantire.ca/en/outdoor-living/...     OUTDOOR HEATING
# 4  https://www.canadiantire.ca/en/outdoor-living/...     OUTDOOR HEATING
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/outdoor-living/...
# 1  https://www.canadiantire.ca/en/outdoor-living/...
# 2  https://www.canadiantire.ca/en/outdoor-living/...
# ...

# %% [markdown]
# ## OUTDOOR LIGHTING

# %%
# Importing required libraries
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/outdoor-living/outdoor-lighting/string-lights.html?adlocation=LIT_Category_Product_StringLightsCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-lighting/patio-lanterns-lights.html?adlocation=LIT_Category_Product_OutdoorDecorLighting_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-lighting/chandeliers-pendants.html?adlocation=LIT_Category_Product_OutdoorChandeliersPendants_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-lighting/deck-fence-lights.html?adlocation=LIT_Category_Product_DeckFenceLightingCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-lighting/landscape-pathway-lights.html?adlocation=LIT_Category_Product_LandscapePathwayLightingCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-lighting/solar-lights.html?adlocation=LIT_CLP_SolarLighting_Deck-Fence-Solar-Lights_en;'
                ]

product_link_name = ['STRING LIGHTS',
                     'PATIO LANTERNS & LIGHTS',
                     'OUTDOOR CHANDELIERS & PENDANTS',
                     'DECK & FENCE LIGHTING',
                     'LANDSCAPE & PATHWAY LIGHTING',
                     'SOLAR LIGHTING'                    
        ]

### FILL THIS OUT######
product = "OUTDOOR_LIGHTING"
maj_name = "OUTDOOR LIGHTING"
maj_link = "https://www.canadiantire.ca/en/outdoor-living/outdoor-lighting.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#        product_name               product_link_name  \
# 0  OUTDOOR_LIGHTING                   STRING LIGHTS
# 1  OUTDOOR_LIGHTING         PATIO LANTERNS & LIGHTS
# 2  OUTDOOR_LIGHTING  OUTDOOR CHANDELIERS & PENDANTS
# 3  OUTDOOR_LIGHTING           DECK & FENCE LIGHTING
# 4  OUTDOOR_LIGHTING    LANDSCAPE & PATHWAY LIGHTING
#
#                                                 link major_category_name  \
# 0  https://www.canadiantire.ca/en/outdoor-living/...    OUTDOOR LIGHTING
# 1  https://www.canadiantire.ca/en/outdoor-living/...    OUTDOOR LIGHTING
# 2  https://www.canadiantire.ca/en/outdoor-living/...    OUTDOOR LIGHTING
# 3  https://www.canadiantire.ca/en/outdoor-living/...    OUTDOOR LIGHTING
# 4  https://www.canadiantire.ca/en/outdoor-living/...    OUTDOOR LIGHTING
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/outdoor-living/...
# 1  https://www.canadiantire.ca/en/outdoor-living/...
# ...

# %% [markdown]
# ## SHEDS & OUTDOOR STORAGE

# %%
# Importing required libraries
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/outdoor-living/sheds-storage/sheds.html?adlocation=LIT_Category_Product_ShedsCat_en;',
'https://www.canadiantire.ca/en/automotive/portable-car-shelters-accessories/portable-storage-sheds.html?adlocation=LIT_Category_PortableStorageShedsCat_en;',
'https://www.canadiantire.ca/en/outdoor-living/sheds-storage/deck-boxes-benches.html?adlocation=LIT_Category_Product_DeckBoxesBenchesCat_en;',
'https://www.canadiantire.ca/en/outdoor-living/sheds-storage/firewood-storage.html?adlocation=LIT_Category_Product_OutdoorTrashCansCat_en;',
'https://www.canadiantire.ca/en/household-pets/cleaning-supplies-vacuums/garbage-cans-bags.html?adlocation=LIT_Category_Product_OutdoorTrashCansCat_en;',
'https://www.canadiantire.ca/en/outdoor-living/sheds-storage/tarpaulins.html?adlocation=LIT_Category_Tarps_Cat_en;',
'https://www.canadiantire.ca/en/automotive/portable-car-shelters-accessories.html?adlocation=LIT_Category_Tarps_Cat_en;']

product_link_name = ['SHEDS',
'PORTABLE STORAGE SHEDS',
'DECK BOXES & STORAGE BENCHES',
'FIREWOOD STORAGE',
'GARBAGE CANS & BAGS',
'TARPS',
'PORTABLE CAR SHELTERS & ACCESSORIES']

### FILL THIS OUT######
product = "SHEDS_OUTDOOR_STORAGE"
maj_name = "SHEDS AND OUTDOOR STORAGE"
maj_link = "https://www.canadiantire.ca/en/outdoor-living/sheds-storage.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#             product_name             product_link_name  \
# 0  SHEDS_OUTDOOR_STORAGE                         SHEDS
# 1  SHEDS_OUTDOOR_STORAGE        PORTABLE STORAGE SHEDS
# 2  SHEDS_OUTDOOR_STORAGE  DECK BOXES & STORAGE BENCHES
# 3  SHEDS_OUTDOOR_STORAGE              FIREWOOD STORAGE
# 4  SHEDS_OUTDOOR_STORAGE           GARBAGE CANS & BAGS
#
#                                                 link  \
# 0  https://www.canadiantire.ca/en/outdoor-living/...
# 1  https://www.canadiantire.ca/en/automotive/port...
# 2  https://www.canadiantire.ca/en/outdoor-living/...
# 3  https://www.canadiantire.ca/en/outdoor-living/...
# 4  https://www.canadiantire.ca/en/household-pets/...
#
#          major_category_name  \
# 0  SHEDS AND OUTDOOR STORAGE
# 1  SHEDS AND OUTDOOR STORAGE
# 2  SHEDS AND OUTDOOR STORAGE
# 3  SHEDS AND OUTDOOR STORAGE
# 4  SHEDS AND OUTDOOR STORAGE
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/outdoor-living/...
# ...

# %% [markdown]
# ## OUTDOOR PLAY

# %%
# Importing required libraries
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/outdoor-living/outdoor-play/trampolines.html?adlocation=LIT_Category_Product_Trampolines_en;',
'https://www.canadiantire.ca/en/outdoor-living/outdoor-play/play-sets-swings-slides.html?adlocation=LIT_Category_Product_PlaysetsSwingsSlides_en;',
'https://www.canadiantire.ca/en/outdoor-living/outdoor-play/inflatable-bouncers.html?adlocation=LIT_Category_Product_InflatableBouncers_en;',
'https://www.canadiantire.ca/en/outdoor-living/outdoor-play/backyard-water-fun.html?adlocation=LIT_Category_Product_BackyardWaterFun_en;',
'https://www.canadiantire.ca/en/outdoor-living/outdoor-play/sandboxes-water-tables.html?adlocation=LIT_Category_Product_PlayhousesSandboxes_en;',
'https://www.canadiantire.ca/en/outdoor-living/outdoor-play/lawn-games.html?adlocation=LIT_Category_Product_LawnGames_en;',
'https://www.canadiantire.ca/en/outdoor-living/outdoor-play/ziplines-slacklines-slackers.html?adlocation=LIT_Category_Product_ZiplinesSlacklineNinjaLines_en;',
'https://www.canadiantire.ca/en/outdoor-living/outdoor-play/sand-beach-toys.html?adlocation=LIT_Category_Product_BeachToys_en;',
'https://www.canadiantire.ca/en/outdoor-living/pools-accessories.html?adlocation=LIT_Category_Product_Pools_en;',
'https://www.canadiantire.ca/en/outdoor-living/outdoor-play/wagons-ride-ons.html?adlocation=LIT_Category_Product_WagonsRideOns_en;',
'https://www.canadiantire.ca/en/sports-rec/skateboards-scooters.html?adlocation=LIT_Category_Product_SkateboardsScooters_en;',
'https://www.canadiantire.ca/en/outdoor-living/outdoor-play/hula-hoops-skipping-ropes-pogo-sticks.html?adlocation=LIT_Category_Product_HulaHoopsSkippingRopesPogoSticks_en;',
'https://www.canadiantire.ca/en/outdoor-living/outdoor-play/toy-blasters.html?adlocation=LIT_Category_Product_ToyBlasters_en;',
'https://www.canadiantire.ca/en/outdoor-living/outdoor-play/playground-balls-ball-games.html?adlocation=LIT_Category_Product_PlaygroundBallsBallGames_en;',
'https://www.canadiantire.ca/en/outdoor-living/outdoor-play/backyard-bubbles.html?adlocation=LIT_Category_Product_Bubbles_en;',
'https://www.canadiantire.ca/en/outdoor-living/outdoor-play/sidewalk-chalk.html?adlocation=LIT_Category_Product_Chalk_en;',
'https://www.canadiantire.ca/en/kids-zone/kids-sports.html?adlocation=LIT_Category_Product_KidsSports_en;',
'https://www.canadiantire.ca/en/outdoor-living/outdoor-play/kids-gardening-bug-kits.html?adlocation=LIT_Category_Product_KidsGardeningBugKits_en;',
'https://www.canadiantire.ca/en/sports-rec/winter-sports.html?adlocation=LIT_Category_Product_WinterSports_en;',
'https://www.canadiantire.ca/en/outdoor-living/outdoor-play/snow-toys.html?adlocation=LIT_Category_Product_SnowToys_en;']

product_link_name = ['BACKYARD TRAMPOLINES AND ACCESSORIES',
'PLAY SETS, SWINGS AND SLIDES',
'INFLATABLE BOUNCERS',
'BACKYARD WATER FUN',
'SANDBOXES AND WATER TABLES',
'LAWN GAMES',
'ZIPLINES SLACKLINES AND SLACKERS',
'SAND AND BEACH TOYS',
'POOLS SPAS AND ACCESSORIES',
'WAGONS AND RIDEONS',
'SKATEBOARDS AND SCOOTERS',
'HULA HOOPS, SKIPPING ROPES AND POGO STICKS',
'TOY BLASTERS',
'PLAYGROUND BALLS AND BALL GAMES',
'BUBBLES',
'SIDEWALK CHALK',
'SPORTS',
'KIDS GARDENING AND BUG KITS',
'WINTER SPORTS GEAR',
'SNOW TOYS'                 
        ]

### FILL THIS OUT######
product = "OUTDOOR_PLAY"
maj_name = "OUTDOOR PLAY" 
maj_link = "https://www.canadiantire.ca/en/outdoor-living/outdoor-play.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#    product_name                     product_link_name  \
# 0  OUTDOOR_PLAY  BACKYARD TRAMPOLINES AND ACCESSORIES
# 1  OUTDOOR_PLAY          PLAY SETS, SWINGS AND SLIDES
# 2  OUTDOOR_PLAY                   INFLATABLE BOUNCERS
# 3  OUTDOOR_PLAY                    BACKYARD WATER FUN
# 4  OUTDOOR_PLAY            SANDBOXES AND WATER TABLES
#
#                                                 link major_category_name  \
# 0  https://www.canadiantire.ca/en/outdoor-living/...        OUTDOOR PLAY
# 1  https://www.canadiantire.ca/en/outdoor-living/...        OUTDOOR PLAY
# 2  https://www.canadiantire.ca/en/outdoor-living/...        OUTDOOR PLAY
# 3  https://www.canadiantire.ca/en/outdoor-living/...        OUTDOOR PLAY
# 4  https://www.canadiantire.ca/en/outdoor-living/...        OUTDOOR PLAY
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/outdoor-living/...
# 1  https://www.canadiantire.ca/en/outdoor-living/...
# ...

# %% [markdown]
# ##  POOLS, SPAS & ACCESSORIES

# %%
# Importing required libraries
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/outdoor-living/pools-accessories/pools.html?adlocation=LIT_Category_OutdoorLiving_PoolsAccessories_Pools_en;',
'https://www.canadiantire.ca/en/outdoor-living/pools-accessories/pool-toys-floats.html?adlocation=LIT_Category_OutdoorLiving_PoolsAccessories_PoolToysFloats_en;',
'https://www.canadiantire.ca/en/outdoor-living/pools-accessories/chemicals.html?adlocation=LIT_Category_OutdoorLiving_PoolsAccessories_PoolSpaChemicals_en;',
'https://www.canadiantire.ca/en/outdoor-living/pools-accessories/pool-cleaning-equipment.html?adlocation=LIT_Category_OutdoorLiving_PoolsAccessories_CleaningEquipment_en;',
'https://www.canadiantire.ca/en/outdoor-living/pools-accessories/pool-accessories.html?adlocation=LIT_Category_OutdoorLiving_PoolsAccessories_PoolPartsAccessories_en;',
'https://www.canadiantire.ca/en/outdoor-living/pools-accessories/spas-accessories.html?adlocation=LIT_Category_OutdoorLiving_PoolsAccessories_SpasAccessories_en;',
'https://www.canadiantire.ca/en/outdoor-living/pools-accessories/goggles-snorkels-swim-caps.html?adlocation=LIT_Category_OutdoorLiving_PoolsAccessories_GogglesSnorkelsSwimCaps_en;',
'https://www.canadiantire.ca/en/outdoor-living/pools-accessories/swim-aids.html?adlocation=LIT_Category_OutdoorLiving_PoolsAccessories_SwimAids_en;',
'https://www.canadiantire.ca/en/sports-rec/camping/first-aid-health-safety/sun-protection.html?adlocation=LIT_Category_OutdoorLiving_PoolsAccessories_SunProtection_en;']

product_link_name = ['POOLS',
'WATER TOYS AND FLOATS',
'POOL AND SPA CHEMICALS',
'POOL CLEANING EQUIPMENT',
'POOL PARTS AND ACCESSORIES',
'SPAS AND ACCESSORIES',
'GOGGLES SNORKELS AND SWIM CAPS',
'SWIM AIDS',
'SUN PROTECTION AND AFTER SUN CARE']

### FILL THIS OUT######
product = "POOLS_SPAS_ACC"
maj_name = "POOLS SPAS AND ACCESSORIES"
maj_link = "https://www.canadiantire.ca/en/outdoor-living/pools-accessories.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#      product_name           product_link_name  \
# 0  POOLS_SPAS_ACC                       POOLS
# 1  POOLS_SPAS_ACC       WATER TOYS AND FLOATS
# 2  POOLS_SPAS_ACC      POOL AND SPA CHEMICALS
# 3  POOLS_SPAS_ACC     POOL CLEANING EQUIPMENT
# 4  POOLS_SPAS_ACC  POOL PARTS AND ACCESSORIES
#
#                                                 link  \
# 0  https://www.canadiantire.ca/en/outdoor-living/...
# 1  https://www.canadiantire.ca/en/outdoor-living/...
# 2  https://www.canadiantire.ca/en/outdoor-living/...
# 3  https://www.canadiantire.ca/en/outdoor-living/...
# 4  https://www.canadiantire.ca/en/outdoor-living/...
#
#           major_category_name  \
# 0  POOLS SPAS AND ACCESSORIES
# 1  POOLS SPAS AND ACCESSORIES
# 2  POOLS SPAS AND ACCESSORIES
# 3  POOLS SPAS AND ACCESSORIES
# 4  POOLS SPAS AND ACCESSORIES
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/outdoor-living/...
# 1  https://www.canadiantire.ca/en/outdoor-living/...
# ...

# %% [markdown]
# ## OUTDOOR DINING & ENTERTAINING

# %%
# Importing required libraries
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/outdoor-living/dining-entertaining/dinnerware.html?adlocation=LIT_OutdoorLiving_OutdoorDrinnerware_en;',
'https://www.canadiantire.ca/en/outdoor-living/dining-entertaining/drinkware-glasses.html?adlocation=LIT_OutdoorLiving_OutdoorDrinkware_en;',
'https://www.canadiantire.ca/en/outdoor-living/dining-entertaining/serveware-platters.html?adlocation=LIT_OutdoorLiving_DiningEntertaining_OutdoorServeware_en;',
'https://www.canadiantire.ca/en/outdoor-living/dining-entertaining/beverage-carts-tubs-coolers.html?adlocation=LIT_OutdoorLiving_DiningEntertaining_BeverageTubsCoolers_en;']

product_link_name = ['OUTDOOR DINNERWARE',
'OUTDOOR DRINKWARE',
'OUTDOOR SERVEWARE',
'BEVERAGE CARTS TUBS AND COOLERS']

### FILL THIS OUT######
product = "OUTDOOR_DINING_ENTERTAINING"
maj_name = "OUTDOOR DINING AND ENTERTAINING"
maj_link = "https://www.canadiantire.ca/en/outdoor-living/dining-entertaining.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#                   product_name                product_link_name  \
# 0  OUTDOOR_DINING_ENTERTAINING               OUTDOOR DINNERWARE
# 1  OUTDOOR_DINING_ENTERTAINING                OUTDOOR DRINKWARE
# 2  OUTDOOR_DINING_ENTERTAINING                OUTDOOR SERVEWARE
# 3  OUTDOOR_DINING_ENTERTAINING  BEVERAGE CARTS TUBS AND COOLERS
#
#                                                 link  \
# 0  https://www.canadiantire.ca/en/outdoor-living/...
# 1  https://www.canadiantire.ca/en/outdoor-living/...
# 2  https://www.canadiantire.ca/en/outdoor-living/...
# 3  https://www.canadiantire.ca/en/outdoor-living/...
#
#                major_category_name  \
# 0  OUTDOOR DINING AND ENTERTAINING
# 1  OUTDOOR DINING AND ENTERTAINING
# 2  OUTDOOR DINING AND ENTERTAINING
# 3  OUTDOOR DINING AND ENTERTAINING
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/outdoor-living/...
# 1  https://www.canadiantire.ca/en/outdoor-living/...
# ...

# %% [markdown]
# ## COOLERS & ICE PACKS

# %%
# Importing required libraries
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/outdoor-living/dining-entertaining/coolers-ice-packs/hard-coolers.html?adlocation=LIT_Category_Product_CoolersCat_en;',
'https://www.canadiantire.ca/en/outdoor-living/dining-entertaining/coolers-ice-packs/soft-coolers.html?adlocation=LIT_Category_Product_CoolersCat_en;',
'https://www.canadiantire.ca/en/outdoor-living/dining-entertaining/coolers-ice-packs/powered-coolers.html?adlocation=LIT_Category_Product_CoolersCat_en;',
'https://www.canadiantire.ca/en/outdoor-living/dining-entertaining/coolers-ice-packs/ice-packs.html?adlocation=LIT_Category_Product_IcepackCat_en;',
'https://www.canadiantire.ca/en/outdoor-living/outdoor-canopies-accessories.html?adlocation=LOL_OutdoorCanopiesAccessories_OutdoorLivingDLP_OutdoorLiving2021_en;']

product_link_name = ['HARD COOLERS',
'SOFT COOLERS',
'POWERED COOLERS',
'ICE PACKS','OUTDOOR CANOPIES & ACCESSORIES']

### FILL THIS OUT######
product = "COOLERS_ICE_PACKS"
maj_name = "COOLERS & ICE PACKS"
maj_link = "https://www.canadiantire.ca/en/outdoor-living/dining-entertaining/coolers-ice-packs.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#         product_name               product_link_name  \
# 0  COOLERS_ICE_PACKS                    HARD COOLERS
# 1  COOLERS_ICE_PACKS                    SOFT COOLERS
# 2  COOLERS_ICE_PACKS                 POWERED COOLERS
# 3  COOLERS_ICE_PACKS                       ICE PACKS
# 4  COOLERS_ICE_PACKS  OUTDOOR CANOPIES & ACCESSORIES
#
#                                                 link  major_category_name  \
# 0  https://www.canadiantire.ca/en/outdoor-living/...  COOLERS & ICE PACKS
# 1  https://www.canadiantire.ca/en/outdoor-living/...  COOLERS & ICE PACKS
# 2  https://www.canadiantire.ca/en/outdoor-living/...  COOLERS & ICE PACKS
# 3  https://www.canadiantire.ca/en/outdoor-living/...  COOLERS & ICE PACKS
# 4  https://www.canadiantire.ca/en/outdoor-living/...  COOLERS & ICE PACKS
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/outdoor-living/...
# 1  https://www.canadiantire.ca/en/outdoor-living/...
# ...
