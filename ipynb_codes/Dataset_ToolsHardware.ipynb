# %% [markdown]
# # Creating tables for link storage

# %% [markdown]
# ## Power Tools

# %%
# Importing required libraries
import pandas as pd

# Creating lists of titles and links for Seat Covers

product_links = ['https://www.canadiantire.ca/en/tools-hardware/power-tools/saws.html?',
        'https://www.canadiantire.ca/en/tools-hardware/power-tools/drills-drivers.html?',
        'https://www.canadiantire.ca/en/tools-hardware/power-tools/combo-kits.html?',
        'https://www.canadiantire.ca/en/tools-hardware/power-tools/sanders.html?',
        'https://www.canadiantire.ca/en/tools-hardware/power-tools/impact-wrenches.html?;',
        'https://www.canadiantire.ca/en/tools-hardware/power-tools/drills-drivers/impact-drivers.html?',
        'https://www.canadiantire.ca/en/tools-hardware/power-tools/rotary-tools.html?',
        'https://www.canadiantire.ca/en/tools-hardware/power-tools/routers.html?',
        'https://www.canadiantire.ca/en/tools-hardware/power-tools/grinders.html?',
        'https://www.canadiantire.ca/en/tools-hardware/power-tools/planers-jointers.html?',
        'https://www.canadiantire.ca/en/tools-hardware/power-tools/heat-guns.html?',
        'https://www.canadiantire.ca/en/tools-hardware/power-tools/oscillating-tools.html?',
        'https://www.canadiantire.ca/en/tools-hardware/power-tool-accessories.html?'
        ]

product_link_name = ['SAWS',
        'DRILLS AND DRIVERS',
        'COMBO KITS',
        'SANDERS',
        'IMPACT WRENCHES',
        'IMPACT DRIVERS',
        'ROTARY TOOLS',
        'ROUTERS',
        'GRINDERS',
        'PLANERS AND JOINTERS',
        'HEAT GUNS',
        'OSCILLATING TOOLS',
        'POWER TOOL ACCESSORIES'
        ]

product_name = ['POWER_TOOLS' for i in range(len(product_links))]

interioracc = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
interioracc['major_category_name'] = 'POWER TOOLS'
interioracc['major_category_link'] = 'https://www.canadiantire.ca/en/tools-hardware/power-tools.html'
interioracc.to_csv('files/power_tools.csv', index=False)
interioracc
# Out:
#    product_name       product_link_name  \
# 0   POWER_TOOLS                    SAWS
# 1   POWER_TOOLS      DRILLS AND DRIVERS
# 2   POWER_TOOLS              COMBO KITS
# 3   POWER_TOOLS                 SANDERS
# 4   POWER_TOOLS         IMPACT WRENCHES
# 5   POWER_TOOLS          IMPACT DRIVERS
# 6   POWER_TOOLS            ROTARY TOOLS
# 7   POWER_TOOLS                 ROUTERS
# 8   POWER_TOOLS                GRINDERS
# 9   POWER_TOOLS    PLANERS AND JOINTERS
# 10  POWER_TOOLS               HEAT GUNS
# 11  POWER_TOOLS       OSCILLATING TOOLS
# 12  POWER_TOOLS  POWER TOOL ACCESSORIES
#
#                                                  link major_category_name  \
# 0   https://www.canadiantire.ca/en/tools-hardware/...         POWER TOOLS
# 1   https://www.canadiantire.ca/en/tools-hardware/...         POWER TOOLS
# 2   https://www.canadiantire.ca/en/tools-hardware/...         POWER TOOLS
# 3   https://www.canadiantire.ca/en/tools-hardware/...         POWER TOOLS
# ...

# %% [markdown]
# ## Hand Tools

# %%
# Importing required libraries
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/tools-hardware/hand-tools/sockets-socket-sets.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/hand-tools/wrenches.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/hand-tools/clamps-vises.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/hand-tools/staple-guns-staples.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/hand-tools/ratchets-breaker-bars.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/hand-tools/screwdrivers-nut-drivers.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/hand-tools/hammers-sledges.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/hand-tools/hex-keys.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/hand-tools/pliers.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/hand-tools/measuring-tools.html?'
                ]

product_link_name = ['SOCKETS AND SOCKET SETS',
                     'WRENCHES',
                     'CLAMPS AND VISES',
                     'STAPLE GUNS AND STAPLES',
                     'RATCHES AND BREAKER BARS',
                     'SCREW DRIVERS AND NUT DRIVERS',
                     'HAMMERS AND SLEDGES',
                     'HEX KEYS',
                     'PLIERS',
                     'MEASURING TOOLS'                    
        ]

### FILL THIS OUT######
product = "HAND_TOOLS"
maj_name = "HAND TOOLS"
maj_link = "https://www.canadiantire.ca/en/tools-hardware/hand-tools.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#   product_name         product_link_name  \
# 0   HAND_TOOLS   SOCKETS AND SOCKET SETS
# 1   HAND_TOOLS                  WRENCHES
# 2   HAND_TOOLS          CLAMPS AND VISES
# 3   HAND_TOOLS   STAPLE GUNS AND STAPLES
# 4   HAND_TOOLS  RATCHES AND BREAKER BARS
#
#                                                 link major_category_name  \
# 0  https://www.canadiantire.ca/en/tools-hardware/...          HAND TOOLS
# 1  https://www.canadiantire.ca/en/tools-hardware/...          HAND TOOLS
# 2  https://www.canadiantire.ca/en/tools-hardware/...          HAND TOOLS
# 3  https://www.canadiantire.ca/en/tools-hardware/...          HAND TOOLS
# 4  https://www.canadiantire.ca/en/tools-hardware/...          HAND TOOLS
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# 2  https://www.canadiantire.ca/en/tools-hardware/...
# 3  https://www.canadiantire.ca/en/tools-hardware/...
# ...

# %% [markdown]
# ## Garage Organization

# %%
import pandas as pd

product_links = ['https://www.canadiantire.ca/en/tools-hardware/garage-storage-organization-solutions/garage-storage-cabinets.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/garage-storage-organization-solutions/garage-wall-ceiling-organization.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/garage-storage-organization-solutions/garage-storage-shelves-racks.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/garage-door-openers-hardware.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/tool-storage-workbenches/tool-chests-cabinets-accessories.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/garage-storage-organization-solutions/utility-carts.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/garage-storage-organization-solutions/garage-workbenches-worktops.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/garage-storage-organization-solutions/plastic-storage-containers-totes.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/garage-storage-organization-solutions/dollies-hand-trucks.html?'
                ]

product_link_name = ['GARAGE STORAGE CABINETS',
                     'GARAGE WALL AND VEILING ORGANIZATION',
                     'GARAGE SHELVING ANS STORAGE RACKS',
                     'GARAGE DOOR OPENERS PARTS AND HARDWARE',
                     'TOOL CHESTS CABINETS AND ACCESSORIES',
                     'UTILITY AND TOOL CARTS',
                     'GARAGE WORKBENCHES WORKTOPS AND TABLES',
                     'PLASTIC STORAGE BINS CONTAINERS AND TOTES',
                     'HAND TRUCKS TROLLEYS AND DOLLY CARTS'                     
        ]

### FILL THIS OUT######
product = 'GARAGE_ORG'
maj_name = 'GARAGE ORGANIZATION AND TOOL STORAGE SOLUTIONS'
maj_link = 'https://www.canadiantire.ca/en/tools-hardware/garage-storage-organization-solutions.html'
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#   product_name                       product_link_name  \
# 0   GARAGE_ORG                 GARAGE STORAGE CABINETS
# 1   GARAGE_ORG    GARAGE WALL AND VEILING ORGANIZATION
# 2   GARAGE_ORG       GARAGE SHELVING ANS STORAGE RACKS
# 3   GARAGE_ORG  GARAGE DOOR OPENERS PARTS AND HARDWARE
# 4   GARAGE_ORG    TOOL CHESTS CABINETS AND ACCESSORIES
#
#                                                 link  \
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# 2  https://www.canadiantire.ca/en/tools-hardware/...
# 3  https://www.canadiantire.ca/en/tools-hardware/...
# 4  https://www.canadiantire.ca/en/tools-hardware/...
#
#                               major_category_name  \
# 0  GARAGE ORGANIZATION AND TOOL STORAGE SOLUTIONS
# 1  GARAGE ORGANIZATION AND TOOL STORAGE SOLUTIONS
# 2  GARAGE ORGANIZATION AND TOOL STORAGE SOLUTIONS
# 3  GARAGE ORGANIZATION AND TOOL STORAGE SOLUTIONS
# 4  GARAGE ORGANIZATION AND TOOL STORAGE SOLUTIONS
#
# ...

# %% [markdown]
# ## TOOL STORAGE & WORKBENCHES

# %%
import pandas as pd

product_links = ['https://www.canadiantire.ca/en/tools-hardware/tool-storage-workbenches/tool-chests-cabinets-accessories.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/tool-storage-workbenches/tool-bags-boxes.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/tool-storage-workbenches/tool-belts-pouches.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/tool-storage-workbenches/tool-workbenches-work-tops.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/tool-storage-workbenches/tool-stands-sawhorses.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/tool-storage-workbenches/tool-carts.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/tool-storage-workbenches/tool-bins-organizers.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/tool-storage-workbenches/tool-wall-organization.html?'
                ]

product_link_name = ['TOOL CHESTS CABINETS AND ACCESSORIES',
                     'TOOL BAGS AND BOXES',
                     'TOOL BELTS AND POUCHES',
                     'TOOL WORKBENCHES AND WORKTOPS',
                     'TOOL STANDS AND SAWHORSES',
                     'TOOL CARTS',
                     'TOOL BINS AND ORGANIZERS',
                     'TOOL WALL ORGANIZATION'
                    ]

### FILL THIS OUT######
product = 'TOOL_STORAGE'
maj_name = 'TOOL STORAGE AND WORKBENCHES'
maj_link = 'https://www.canadiantire.ca/en/tools-hardware/tool-storage-workbenches.html'
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#    product_name                     product_link_name  \
# 0  TOOL_STORAGE  TOOL CHESTS CABINETS AND ACCESSORIES
# 1  TOOL_STORAGE                   TOOL BAGS AND BOXES
# 2  TOOL_STORAGE                TOOL BELTS AND POUCHES
# 3  TOOL_STORAGE         TOOL WORKBENCHES AND WORKTOPS
# 4  TOOL_STORAGE             TOOL STANDS AND SAWHORSES
#
#                                                 link  \
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# 2  https://www.canadiantire.ca/en/tools-hardware/...
# 3  https://www.canadiantire.ca/en/tools-hardware/...
# 4  https://www.canadiantire.ca/en/tools-hardware/...
#
#             major_category_name  \
# 0  TOOL STORAGE AND WORKBENCHES
# 1  TOOL STORAGE AND WORKBENCHES
# 2  TOOL STORAGE AND WORKBENCHES
# 3  TOOL STORAGE AND WORKBENCHES
# 4  TOOL STORAGE AND WORKBENCHES
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# ...

# %% [markdown]
# ## POWER TOOL ACCESSORIES

# %%
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/tools-hardware/power-tool-accessories/drill-bits-accessories.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/power-tool-accessories/saw-blades-accessories.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/power-tool-accessories/power-tool-batteries-chargers.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/power-tool-accessories/grinder-accessories.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/power-tool-accessories/sander-accessories.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/power-tool-accessories/oscillating-tool-accessories.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/power-tool-accessories/rotary-tool-bits-accessories.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/power-tool-accessories/router-bits-accessories.html?',
                 'https://www.canadiantire.ca/en/tools-hardware/power-tool-accessories/buffer-polisher-accessories.html?',
                 
                 
                ]

product_link_name = ['DRILL BITS',
                     'SAW BLADES AND ACCESSORIES',
                     'POWER TOOL BATTERIES',
                     'CUTTING AND GRINDING ACCESSORIES',
                     'SANDPAPER AND ACCESSORIES',
                     'OSCILLATING TOOL ACCESSORIES',
                     'ROTARY TOOL BITS AND ACCESSORIES',
                     'ROUTER BITS AND ACCESSORIES',
                     'BUFFER POLISHER ACCESSORIES'
        ]

### FILL THIS OUT######
product = "POWER_TOOL_ACC"
maj_name = "POWER TOOL ACCESSORIES"
maj_link = "https://www.canadiantire.ca/en/tools-hardware/power-tool-accessories.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#      product_name                 product_link_name  \
# 0  POWER_TOOL_ACC                        DRILL BITS
# 1  POWER_TOOL_ACC        SAW BLADES AND ACCESSORIES
# 2  POWER_TOOL_ACC              POWER TOOL BATTERIES
# 3  POWER_TOOL_ACC  CUTTING AND GRINDING ACCESSORIES
# 4  POWER_TOOL_ACC         SANDPAPER AND ACCESSORIES
#
#                                                 link     major_category_name  \
# 0  https://www.canadiantire.ca/en/tools-hardware/...  POWER TOOL ACCESSORIES
# 1  https://www.canadiantire.ca/en/tools-hardware/...  POWER TOOL ACCESSORIES
# 2  https://www.canadiantire.ca/en/tools-hardware/...  POWER TOOL ACCESSORIES
# 3  https://www.canadiantire.ca/en/tools-hardware/...  POWER TOOL ACCESSORIES
# 4  https://www.canadiantire.ca/en/tools-hardware/...  POWER TOOL ACCESSORIES
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# ...

# %% [markdown]
# ## WELDING SUPPLIES

# %%
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/tools-hardware/welding-soldering-torches/welders-cutters.html?adlocation=LIT_Category_Product_WeldersCuttersCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/welding-soldering-torches/solders-soldering-supplies.html?adlocation=LIT_Category_Product_SoldersSolderingSuppliesCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/welding-soldering-torches/torches-accessories.html?adlocation=LIT_Category_Product_HandheldTorchesTanksCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/welding-soldering-torches/welding-wires-rods-accessories.html?adlocation=LIT_Welding_WeldingWireAccessories_WeldingSteels_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/welding-soldering-torches/welding-helmets-safety-glasses.html?adlocation=LIT_Category_Product_WeldingSafetyGearCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/welding-soldering-torches/welding-gloves-apparel.html?adlocation=LIT_Category_Product_WeldingSafetyGearCat_en;'
                ]

product_link_name = ['WELDERS AND CUTTERS',
                     'SOLDERS AND SOLDERING SUPPLIES',
                     'TORCHES AND ACCESSORIES',
                     'WELDING WIRES RODS AND ACCESSORIES',
                     'WELDING HELMETS AND SAFETY GLASSES',
                     'WELDING GLOVES AND APPARELS'
        ]

### FILL THIS OUT######
product = "WELDING_SUPPLIES"
maj_name = "WELDING SUPPLIES"
maj_link = "https://www.canadiantire.ca/en/tools-hardware/welding-soldering-torches.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#        product_name                   product_link_name  \
# 0  WELDING_SUPPLIES                 WELDERS AND CUTTERS
# 1  WELDING_SUPPLIES      SOLDERS AND SOLDERING SUPPLIES
# 2  WELDING_SUPPLIES             TORCHES AND ACCESSORIES
# 3  WELDING_SUPPLIES  WELDING WIRES RODS AND ACCESSORIES
# 4  WELDING_SUPPLIES  WELDING HELMETS AND SAFETY GLASSES
#
#                                                 link major_category_name  \
# 0  https://www.canadiantire.ca/en/tools-hardware/...    WELDING SUPPLIES
# 1  https://www.canadiantire.ca/en/tools-hardware/...    WELDING SUPPLIES
# 2  https://www.canadiantire.ca/en/tools-hardware/...    WELDING SUPPLIES
# 3  https://www.canadiantire.ca/en/tools-hardware/...    WELDING SUPPLIES
# 4  https://www.canadiantire.ca/en/tools-hardware/...    WELDING SUPPLIES
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# ...

# %%
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/tools-hardware/electrical/door-bells-chimes.html?adlocation=LIT_Category_Product_DoorBellsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/electrical/dimmers-switches-timers.html?adlocation=LIT_Category_Product_DimmersSwitchesTimersCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/electrical/electrical-plugs-connectors-adapters.html?adlocation=LIT_Category_Product_ElectricalPlugsConnectorsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/electrical/extension-cords.html?adlocation=LIT_Category_Product_Electrical_ExtensionCordsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/electrical/fuses-breakers-panel-boxes.html?adlocation=LIT_Category_Product_FusesBreakersPanelBoxesConnectorsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/electrical/lighting-hardware-accessories.html?adlocation=LIT_Category_Product_LightingHardwareAccessoriesCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/electrical/multi-media-cables-accessories.html?adlocation=LIT_Category_Product_MultiMediaCablesCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/electrical/portable-work-lights.html?adlocation=LIT_Category_Product_PortableWorkLightsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/electrical/power-bars-surge-protectors.html?adlocation=LIT_Category_Product_PowerBarsAndSurgeProtectorsCatt_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/electrical/switch-wall-plates.html?adlocation=LIT_Category_Product_SwitchAndWallPlatesCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/electrical/wiring/wire-connectors.html?adlocation=LIT_Category_Product_WireConnectorsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/electrical/wiring.html?adlocation=LIT_Category_Product_WiringCat_en;'
                ]

product_link_name = ['DOORBELL AND CHIMES',
                     'DIMMERS SWITCHES AND TIMERS',
                     'ELECTRICAL PLUGS CONNECTORS AND TIMERS',
                     'EXTENSION CORDS',
                     'FUSES BREAKERS AND PANEL BOXES',
                     'LIGHTING HARDWARE ACCESSORIES',
                     'MULTIMEDIA CABLES AND ACCESSORIES',
                     'PORTABLE WORKLIGHTS',
                     'POWER BARS AND SURGE PROTECTORS',
                     'SWITCH AND WALL PLATES',
                     'WIRE CONNECTORS',
                     'WIRING'
        ]

### FILL THIS OUT######
product = "ELECTRICAL_SUPPLIES"
maj_name = 'ELECTRICAL SUPPLIES & EQUIPMENT'
maj_link = "https://www.canadiantire.ca/en/tools-hardware/electrical.html?"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#           product_name                       product_link_name  \
# 0  ELECTRICAL_SUPPLIES                     DOORBELL AND CHIMES
# 1  ELECTRICAL_SUPPLIES             DIMMERS SWITCHES AND TIMERS
# 2  ELECTRICAL_SUPPLIES  ELECTRICAL PLUGS CONNECTORS AND TIMERS
# 3  ELECTRICAL_SUPPLIES                         EXTENSION CORDS
# 4  ELECTRICAL_SUPPLIES          FUSES BREAKERS AND PANEL BOXES
#
#                                                 link  \
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# 2  https://www.canadiantire.ca/en/tools-hardware/...
# 3  https://www.canadiantire.ca/en/tools-hardware/...
# 4  https://www.canadiantire.ca/en/tools-hardware/...
#
#                major_category_name  \
# 0  ELECTRICAL SUPPLIES & EQUIPMENT
# 1  ELECTRICAL SUPPLIES & EQUIPMENT
# 2  ELECTRICAL SUPPLIES & EQUIPMENT
# 3  ELECTRICAL SUPPLIES & EQUIPMENT
# 4  ELECTRICAL SUPPLIES & EQUIPMENT
#
# ...

# %% [markdown]
# ## PLUMBING SUPPLIES

# %%
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/tools-hardware/plumbing/faucet-repair-parts.html?adlocation=LIT_Category_Product_FaucetsFixturesCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/plumbing/sink-repair-parts-drainage.html?adlocation=LIT_Category_Product_SinksCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/plumbing/pipes-fittings.html?adlocation=LIT_Category_Product_PipesFittingsValvesCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/plumbing/toilet-repair-parts.html?adlocation=LIT_Category_Product_ToiletsHardwareCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/plumbing/drain-openers-plungers-tools.html?adlocation=LIT_Category_Product_DrainOpenersPlungersCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/plumbing/water-filtration-treatment.html?adlocation=LIT_Category_Product_WaterFiltrationTreatmentsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/plumbing/water-heaters-parts.html?adlocation=LIT_Category_Product_WaterHeatersCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/plumbing/water-pumps-parts-accessories.html?adlocation=LIT_Category_Product_DrainOpenersPlungersCat_en;'
                ]

product_link_name = ['FAUCET REPAIR PARTS',
                     'SINK REPAIR PARTS AND DRAINAGE',
                     'PIPE AND FITTINGS',
                     'TOILET REPAIR PARTS',
                     'DRAIN OPENERS PLUNGERS AND TOOLS',
                     'WATER FILTRATION AND TREATMENT',
                     'WATER HEATERS',
                     'WATER PUMPS'
        ]

### FILL THIS OUT######
product = "PLUMBING_SUPPLIES"
maj_name = "PLUMBING SUPPLIES"
maj_link = "https://www.canadiantire.ca/en/tools-hardware/plumbing.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#         product_name                 product_link_name  \
# 0  PLUMBING_SUPPLIES               FAUCET REPAIR PARTS
# 1  PLUMBING_SUPPLIES    SINK REPAIR PARTS AND DRAINAGE
# 2  PLUMBING_SUPPLIES                 PIPE AND FITTINGS
# 3  PLUMBING_SUPPLIES               TOILET REPAIR PARTS
# 4  PLUMBING_SUPPLIES  DRAIN OPENERS PLUNGERS AND TOOLS
#
#                                                 link major_category_name  \
# 0  https://www.canadiantire.ca/en/tools-hardware/...   PLUMBING SUPPLIES
# 1  https://www.canadiantire.ca/en/tools-hardware/...   PLUMBING SUPPLIES
# 2  https://www.canadiantire.ca/en/tools-hardware/...   PLUMBING SUPPLIES
# 3  https://www.canadiantire.ca/en/tools-hardware/...   PLUMBING SUPPLIES
# 4  https://www.canadiantire.ca/en/tools-hardware/...   PLUMBING SUPPLIES
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# ...

# %% [markdown]
# ## GARAGE DOOR OPENERS, PARTS & HARDWARE

# %%
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/tools-hardware/garage-door-openers-hardware/garage-door-openers.html?adlocation=LIT_Category_Product_GarageDoorOpenersHardware_Cat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/garage-door-openers-hardware/garage-door-keypads-remotes.html?adlocation=LIT_Category_Product_GarageDoorKeypadsRemotes_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/garage-door-openers-hardware/garage-door-extension-kits-accessories.html?adlocation=LIT_Category_Product_GarageDoorExtensionKitsAssec_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/garage-door-openers-hardware/garage-door-handles-hinges-rollers-accessories.html?adlocation=LIT_Category_Product_GarageDoorHandlesHinges_en;',
                 'https://www.canadiantire.ca/en/automotive/batteries-maintenance-accessories/sla-batteries.html?adlocation=LIT_Category_Product_SlaBatteries_Cat_en;'
                ]

product_link_name = ['GARAGE DOOR OPENERS',
                     'GARAGE DOOR KEYPADS AND REMOTES',
                     'EXTENSION KITS AND ACCESSORIES',
                     'HANDLES HINGES ROLLERS',
                     'SEALED LEAD ACID'
        ]

### FILL THIS OUT######
product = "GARAGE_DOOR_OPENERS"
maj_name = "GARAGE DOOR OPENERS, PARTS & HARDWARE"
maj_link = "https://www.canadiantire.ca/en/tools-hardware/garage-door-openers-hardware.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#           product_name                product_link_name  \
# 0  GARAGE_DOOR_OPENERS              GARAGE DOOR OPENERS
# 1  GARAGE_DOOR_OPENERS  GARAGE DOOR KEYPADS AND REMOTES
# 2  GARAGE_DOOR_OPENERS   EXTENSION KITS AND ACCESSORIES
# 3  GARAGE_DOOR_OPENERS           HANDLES HINGES ROLLERS
# 4  GARAGE_DOOR_OPENERS                 SEALED LEAD ACID
#
#                                                 link  \
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# 2  https://www.canadiantire.ca/en/tools-hardware/...
# 3  https://www.canadiantire.ca/en/tools-hardware/...
# 4  https://www.canadiantire.ca/en/automotive/batt...
#
#                      major_category_name  \
# 0  GARAGE DOOR OPENERS, PARTS & HARDWARE
# 1  GARAGE DOOR OPENERS, PARTS & HARDWARE
# 2  GARAGE DOOR OPENERS, PARTS & HARDWARE
# 3  GARAGE DOOR OPENERS, PARTS & HARDWARE
# 4  GARAGE DOOR OPENERS, PARTS & HARDWARE
#
# ...

# %% [markdown]
# ## LADDERS AND SCAFFOLDING

# %%
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/tools-hardware/ladders-scaffolding/step-stools.html?adlocation=LIT_Category_Product_StepStoolsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/ladders-scaffolding/step-ladders.html?adlocation=LIT_Category_Product_StepLaddersCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/ladders-scaffolding/extension-ladders.html?adlocation=LIT_Category_Product_LaddersCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/ladders-scaffolding/multi-position-ladders.html?adlocation=LIT_Category_Product_MultiPositionalLaddersCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/ladders-scaffolding/scaffolding.html?adlocation=LIT_Category_Product_ScaffoldingSystemsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/ladders-scaffolding/ladder-scaffolding-accessories.html?adlocation=LIT_Category_Product_LadderScaffoldingAccessoriesCat_en;'
                ]

product_link_name = ['STEP TOOLS',
                     'STEP LADDERS',
                     'EXTENSION LADDERS',
                     'MUTI POSITION LADDERS',
                     'SCAFFOLDING',
                     'LADDER ANS SCAFFOLDING ACCESSORIES'
        ]

### FILL THIS OUT######
product = "LADDERS_SCAFFOLDING"
maj_name = "LADDERS AND SCAFFOLDING"
maj_link = "https://www.canadiantire.ca/en/tools-hardware/ladders-scaffolding.html"

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#           product_name      product_link_name  \
# 0  LADDERS_SCAFFOLDING             STEP TOOLS
# 1  LADDERS_SCAFFOLDING           STEP LADDERS
# 2  LADDERS_SCAFFOLDING      EXTENSION LADDERS
# 3  LADDERS_SCAFFOLDING  MUTI POSITION LADDERS
# 4  LADDERS_SCAFFOLDING            SCAFFOLDING
#
#                                                 link      major_category_name  \
# 0  https://www.canadiantire.ca/en/tools-hardware/...  LADDERS AND SCAFFOLDING
# 1  https://www.canadiantire.ca/en/tools-hardware/...  LADDERS AND SCAFFOLDING
# 2  https://www.canadiantire.ca/en/tools-hardware/...  LADDERS AND SCAFFOLDING
# 3  https://www.canadiantire.ca/en/tools-hardware/...  LADDERS AND SCAFFOLDING
# 4  https://www.canadiantire.ca/en/tools-hardware/...  LADDERS AND SCAFFOLDING
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# 2  https://www.canadiantire.ca/en/tools-hardware/...
# ...

# %% [markdown]
# ## AIR TOOLS AND COMPRESSORS

# %%
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/tools-hardware/air-tools-compressors/air-compressors.html?adlocation=LIT_Category_Product_AirCompressorsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/air-tools-compressors/air-tools.html?adlocation=LIT_Category_Product_AirToolsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/air-tools-compressors/air-tool-accessories.html?adlocation=LIT_Category_Product_AirToolAccessoriesCat_en;'
                ]

product_link_name = ['AIR COMPRESSORS',
                     'AIR TOOLS',
                     'AIR TOOL ACCESSORIES'
        ]

### FILL THIS OUT######
product = "AIR_TOOLS"
maj_name = "AIR TOOLS AMD COMPRESSORS"
maj_link = "https://www.canadiantire.ca/en/tools-hardware/air-tools-compressors.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#   product_name     product_link_name  \
# 0    AIR_TOOLS       AIR COMPRESSORS
# 1    AIR_TOOLS             AIR TOOLS
# 2    AIR_TOOLS  AIR TOOL ACCESSORIES
#
#                                                 link  \
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# 2  https://www.canadiantire.ca/en/tools-hardware/...
#
#          major_category_name  \
# 0  AIR TOOLS AMD COMPRESSORS
# 1  AIR TOOLS AMD COMPRESSORS
# 2  AIR TOOLS AMD COMPRESSORS
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# 2  https://www.canadiantire.ca/en/tools-hardware/...

# %% [markdown]
# ## WORKWEAR AND SAFETY GEAR

# %%
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/tools-hardware/work-wear-safety-gear/breathing-protection.html?adlocation=LIT_Category_Product_BreathingProtectionCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/work-wear-safety-gear/eye-protection.html?adlocation=LIT_Category_Product_EyeProtectionCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/work-wear-safety-gear/hard-hats.html?adlocation=LIT_Category_Product_HardHatsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/work-wear-safety-gear/hearing-protection.html?adlocation=LIT_Category_Product_HearingProtectionCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/work-wear-safety-gear/knee-pads.html?adlocation=LIT_Category_Product_KneePadsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/work-wear-safety-gear/work-gloves.html?adlocation=LIT_Category_Product_WorkGlovesCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/work-wear-safety-gear/work-apparel.html?adlocation=LIT_Category_Product_WorkApparelCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/work-wear-safety-gear/work-boots.html?adlocation=LIT_Category_Product_WorkBootsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/welding-soldering-torches/welding-helmets-safety-glasses.html?adlocation=LIT_Category_Product_WeldingSafetyGearCat_en;'
                ]

product_link_name = ['PROTECTIVE FACE MASK AND COVERINGS',
                     'EYE PROTECTION',
                     'HARD HATS',
                     'HEARING PROTECTION',
                     'KNEE PADS',
                     'WORK GLOVES',
                     'WORK APPAREL',
                     'WORK BOOTS AND SAFETY SHOES',
                     'WELDING HELMETS AND SAFETY GLASSES'
        ]

### FILL THIS OUT######
product = "WORKWEAR_SAFETY_GEAR"
maj_name = "WORKWEAR AND SAFETY GEAR"
maj_link = "https://www.canadiantire.ca/en/tools-hardware/work-wear-safety-gear.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#            product_name                   product_link_name  \
# 0  WORKWEAR_SAFETY_GEAR  PROTECTIVE FACE MASK AND COVERINGS
# 1  WORKWEAR_SAFETY_GEAR                      EYE PROTECTION
# 2  WORKWEAR_SAFETY_GEAR                           HARD HATS
# 3  WORKWEAR_SAFETY_GEAR                  HEARING PROTECTION
# 4  WORKWEAR_SAFETY_GEAR                           KNEE PADS
#
#                                                 link  \
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# 2  https://www.canadiantire.ca/en/tools-hardware/...
# 3  https://www.canadiantire.ca/en/tools-hardware/...
# 4  https://www.canadiantire.ca/en/tools-hardware/...
#
#         major_category_name                                major_category_link
# 0  WORKWEAR AND SAFETY GEAR  https://www.canadiantire.ca/en/tools-hardware/...
# 1  WORKWEAR AND SAFETY GEAR  https://www.canadiantire.ca/en/tools-hardware/...
# ...

# %%
## BLOWERS, SHOP VACUUMS, VACS & VACUUM ACCESSORIES

# %%
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/tools-hardware/shop-vacuums-air-movers/shop-vacuums.html?adlocation=LIT_Category_Product_ShopVacuumsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/shop-vacuums-air-movers/air-movers.html?adlocation=LIT_Category_Product_AirMoversCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/shop-vacuums-air-movers/filters-bags.html?adlocation=LIT_Category_Product_ShopVacuumFiltersBagsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/shop-vacuums-air-movers/hose-accessories.html?adlocation=LIT_Category_Product_ShopVacuumHoseAccessoriesCat_en;'
                ]

product_link_name = ['WET DRY VACUUMS',
                     'AIR MOVERS',
                     'FILTERS AND BAGS',
                     'HOSE ACCESSORIES'
        ]

### FILL THIS OUT######
product = "SHOP_VACUUMS_AIR_MOVERS" 
maj_name = "SHOP VACUUMS AND AIR MOVERS"
maj_link = "https://www.canadiantire.ca/en/tools-hardware/shop-vacuums-air-movers.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#               product_name product_link_name  \
# 0  SHOP_VACUUMS_AIR_MOVERS   WET DRY VACUUMS
# 1  SHOP_VACUUMS_AIR_MOVERS        AIR MOVERS
# 2  SHOP_VACUUMS_AIR_MOVERS  FILTERS AND BAGS
# 3  SHOP_VACUUMS_AIR_MOVERS  HOSE ACCESSORIES
#
#                                                 link  \
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# 2  https://www.canadiantire.ca/en/tools-hardware/...
# 3  https://www.canadiantire.ca/en/tools-hardware/...
#
#            major_category_name  \
# 0  SHOP VACUUMS AND AIR MOVERS
# 1  SHOP VACUUMS AND AIR MOVERS
# 2  SHOP VACUUMS AND AIR MOVERS
# 3  SHOP VACUUMS AND AIR MOVERS
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# 2  https://www.canadiantire.ca/en/tools-hardware/...
# 3  https://www.canadiantire.ca/en/tools-hardware/...

# %% [markdown]
# ## MEASURING TOOLS

# %%
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/tools-hardware/hand-tools/measuring-tools/levels.html?adlocation=LIT_Category_Product_LevelsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/hand-tools/measuring-tools/squares-rulers.html?adlocation=LIT_Category_Product_SquaresCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/hand-tools/measuring-tools/stud-finders.html?adlocation=LIT_Category_Product_StudFinders_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/hand-tools/measuring-tools/tape-measures.html?adlocation=LIT_Category_Product_TapeMeasuresCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/hand-tools/measuring-tools/specialty-measuring-tools.html?adlocation=LIT_Category_Product_SpecialtyMeasuringToolsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/hand-tools/measuring-tools/writing-utensils.html?adlocation=LIT_Category_Product_WritingUtensilsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/hand-tools/measuring-tools/chalk-chalk-lines.html?adlocation=LIT_Category_Product_ChalkChalkLinesCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/hand-tools/measuring-tools/flagging-tape.html?adlocation=LIT_Category_Product_FlaggingTapeCat_en'
                ]

product_link_name = ['LEVELS',
                     'SQUARES AND RULERS',
                     'STUD FINDERS',
                     'TAPE MEASURES',
                     'SPECIALTY MEASURING TOOLS',
                     'WRITING UTENSILS',
                     'CHALK AND CHALK LINES',
                     'FLAGGING TAPE'
        ]

### FILL THIS OUT######
product = "MEASURING_TOOLS"
maj_name = "MEASURING TOOLS"
maj_link = "https://www.canadiantire.ca/en/tools-hardware/hand-tools/measuring-tools.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#       product_name          product_link_name  \
# 0  MEASURING_TOOLS                     LEVELS
# 1  MEASURING_TOOLS         SQUARES AND RULERS
# 2  MEASURING_TOOLS               STUD FINDERS
# 3  MEASURING_TOOLS              TAPE MEASURES
# 4  MEASURING_TOOLS  SPECIALTY MEASURING TOOLS
#
#                                                 link major_category_name  \
# 0  https://www.canadiantire.ca/en/tools-hardware/...     MEASURING TOOLS
# 1  https://www.canadiantire.ca/en/tools-hardware/...     MEASURING TOOLS
# 2  https://www.canadiantire.ca/en/tools-hardware/...     MEASURING TOOLS
# 3  https://www.canadiantire.ca/en/tools-hardware/...     MEASURING TOOLS
# 4  https://www.canadiantire.ca/en/tools-hardware/...     MEASURING TOOLS
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# 2  https://www.canadiantire.ca/en/tools-hardware/...
# ...

# %% [markdown]
# ## HARDWARE

# %%
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/tools-hardware/hardware/cabinet-hardware.html?adlocation=LIT_Category_Product_Cabinet%20HardwareCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/hardware/closet-system-hardware.html?adlocation=LIT_Category_Product_ClosetSystemsHardwareCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/hardware/door-hardware-accessories.html?adlocation=LIT_Category_Product_DoorHardwareCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/hardware/exterior-home-hardware.html?adlocation=LIT_Category_Product_HouseNumbersCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/garage-door-openers-hardware.html?adlocation=LIT_Category_Product_GarageDoorOpenersHardwareCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/hardware/nails-screws-fasteners.html?adlocation=LIT_Category_Product_FastenersCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/hardware/ropes-chains.html?adlocation=LIT_Category_Product_ChainsRopesCablesCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/hardware/structural-hardare.html?adlocation=LIT_Category_Product_StructuralHardwareCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/hardware/window-hardware.html?adlocation=LIT_Category_Product_WindowHardwareCat_en;'
                ]

product_link_name = ['CABINET HARDWARE',
                     'CLOSET SYSTEM HARDWARE',
                     'DOOR HARDWARE ACCESSORIES',
                     'EXTERIO HOME HARDWARE',
                     'GARAGE DOOR OPENERS AND HARDWARE',
                     'NAILS SCREWS AND FASTENERS',
                     'ROPES AND CHAINS',
                     'STRUCTURAL HARDWARE',
                     'WINDOW HARDWARE'
        ]

### FILL THIS OUT######
product = "HARDWARE"
maj_name = "HARDWARE"
maj_link = "https://www.canadiantire.ca/en/tools-hardware/hardware.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#   product_name                 product_link_name  \
# 0     HARDWARE                  CABINET HARDWARE
# 1     HARDWARE            CLOSET SYSTEM HARDWARE
# 2     HARDWARE         DOOR HARDWARE ACCESSORIES
# 3     HARDWARE             EXTERIO HOME HARDWARE
# 4     HARDWARE  GARAGE DOOR OPENERS AND HARDWARE
#
#                                                 link major_category_name  \
# 0  https://www.canadiantire.ca/en/tools-hardware/...            HARDWARE
# 1  https://www.canadiantire.ca/en/tools-hardware/...            HARDWARE
# 2  https://www.canadiantire.ca/en/tools-hardware/...            HARDWARE
# 3  https://www.canadiantire.ca/en/tools-hardware/...            HARDWARE
# 4  https://www.canadiantire.ca/en/tools-hardware/...            HARDWARE
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# 2  https://www.canadiantire.ca/en/tools-hardware/...
# ...

# %%
## PAINTS AND STAINS

# %%
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/paints-stains/interior-paints-trim.html?',
                 'https://www.canadiantire.ca/en/paints-stains/interior-stains-finishes.html?',
                 'https://www.canadiantire.ca/en/paints-stains/exterior-paints.html?',
                 'https://www.canadiantire.ca/en/paints-stains/exterior-stains-sealers.html?',
                 'https://www.canadiantire.ca/en/paints-stains/primers.html?',
                 'https://www.canadiantire.ca/en/paints-stains/spray-paint.html?',
                 'https://www.canadiantire.ca/en/paints-stains/floor-paints-sealers.html?',
                 'https://www.canadiantire.ca/en/paints-stains/specialty-paint.html?'
                ]

product_link_name = ['INTERIOR PAINTS AND TRIM',
                     'INTERIOR STAINS AND FINISHES',
                     'EXTERIOR PAINTS',
                     'EXTERIOR STAINS AND SEALERS',
                     'PRIMERS',
                     'SPRAY PAINTS',
                     'FLOOR PAINTS AND SEALERS',
                     'SPECIALTY PAINTS'
        ]

### FILL THIS OUT######
product = "PAINTS_STAINS"
maj_name = "PAINTS AND STAINS"
maj_link = "https://www.canadiantire.ca/en/paints-stains.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#     product_name             product_link_name  \
# 0  PAINTS_STAINS      INTERIOR PAINTS AND TRIM
# 1  PAINTS_STAINS  INTERIOR STAINS AND FINISHES
# 2  PAINTS_STAINS               EXTERIOR PAINTS
# 3  PAINTS_STAINS   EXTERIOR STAINS AND SEALERS
# 4  PAINTS_STAINS                       PRIMERS
#
#                                                 link major_category_name  \
# 0  https://www.canadiantire.ca/en/paints-stains/i...   PAINTS AND STAINS
# 1  https://www.canadiantire.ca/en/paints-stains/i...   PAINTS AND STAINS
# 2  https://www.canadiantire.ca/en/paints-stains/e...   PAINTS AND STAINS
# 3  https://www.canadiantire.ca/en/paints-stains/e...   PAINTS AND STAINS
# 4  https://www.canadiantire.ca/en/paints-stains/p...   PAINTS AND STAINS
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/paints-stains.html
# 1  https://www.canadiantire.ca/en/paints-stains.html
# 2  https://www.canadiantire.ca/en/paints-stains.html
# ...

# %% [markdown]
# ## EXTERIOR REPAIR AND MAINTENANCE SUPPLIES

# %%
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/tools-hardware/exterior-repair-maintenance-supplies/concrete-driveway-repair.html?adlocation=LIT_Category_Product_ConcreteDrivewayRepairCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/exterior-repair-maintenance-supplies/eavestroughs-accessories.html?adlocation=LIT_Category_Product_EavestroughsAccessoriesCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/exterior-repair-maintenance-supplies/roof-repair-maintenance.html?adlocation=LIT_Category_Product_RoofRepairMaintenanceCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/exterior-repair-maintenance-supplies/screen-door-repair.html?adlocation=LIT_Category_Product_ScreenDoorRepairCat_en;'
                ]

product_link_name = ['CONCRETE AND DRIVEWAY REPAIR',
                     'EAVESTROUGHS AND ACCESSORIES',
                     'ROOF REPAIR AND MAINTENANCE',
                     'SCREEN DOOR REPAIR'
        ]

### FILL THIS OUT######
product = "EXTERIOR_REPAIR"
maj_name = "EXTERIOR REPAIR AND MAINTENANCE SUPPLIES"
maj_link = "https://www.canadiantire.ca/en/tools-hardware/exterior-repair-maintenance-supplies.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#       product_name             product_link_name  \
# 0  EXTERIOR_REPAIR  CONCRETE AND DRIVEWAY REPAIR
# 1  EXTERIOR_REPAIR  EAVESTROUGHS AND ACCESSORIES
# 2  EXTERIOR_REPAIR   ROOF REPAIR AND MAINTENANCE
# 3  EXTERIOR_REPAIR            SCREEN DOOR REPAIR
#
#                                                 link  \
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# 2  https://www.canadiantire.ca/en/tools-hardware/...
# 3  https://www.canadiantire.ca/en/tools-hardware/...
#
#                         major_category_name  \
# 0  EXTERIOR REPAIR AND MAINTENANCE SUPPLIES
# 1  EXTERIOR REPAIR AND MAINTENANCE SUPPLIES
# 2  EXTERIOR REPAIR AND MAINTENANCE SUPPLIES
# 3  EXTERIOR REPAIR AND MAINTENANCE SUPPLIES
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# 2  https://www.canadiantire.ca/en/tools-hardware/...
# ...

# %% [markdown]
# ## CAULKING AND ADHESIVES

# %%
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/tools-hardware/caulking-adhesives/adhesives.html?adlocation=LIT_Category_Product_Adhesive_SuperGlueCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/caulking-adhesives/carpenters-glue.html?adlocation=LIT_Category_Product_CarpentersGlueCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/caulking-adhesives/caulk.html?adlocation=LIT_Category_Product_CaulkCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/caulking-adhesives/caulking-guns.html?adlocation=LIT_Category_Product_CaulkingGunsCat_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/caulking-adhesives/tapes.html?adlocation=LIT_Category_Product_PackingTapeCat_en;'
                ]

product_link_name = ['ADHESIVES',
                     'CARPENTERS GLUE',
                     'CAULK',
                     'CAULKING GUNS',
                     'TAPES'
        ]

### FILL THIS OUT######
product = "CAULKING_ADHESIVES"
maj_name = "CAULKING AND ADHESIVES"
maj_link = "https://www.canadiantire.ca/en/tools-hardware/caulking-adhesives.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#          product_name product_link_name  \
# 0  CAULKING_ADHESIVES         ADHESIVES
# 1  CAULKING_ADHESIVES   CARPENTERS GLUE
# 2  CAULKING_ADHESIVES             CAULK
# 3  CAULKING_ADHESIVES     CAULKING GUNS
# 4  CAULKING_ADHESIVES             TAPES
#
#                                                 link     major_category_name  \
# 0  https://www.canadiantire.ca/en/tools-hardware/...  CAULKING AND ADHESIVES
# 1  https://www.canadiantire.ca/en/tools-hardware/...  CAULKING AND ADHESIVES
# 2  https://www.canadiantire.ca/en/tools-hardware/...  CAULKING AND ADHESIVES
# 3  https://www.canadiantire.ca/en/tools-hardware/...  CAULKING AND ADHESIVES
# 4  https://www.canadiantire.ca/en/tools-hardware/...  CAULKING AND ADHESIVES
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# 2  https://www.canadiantire.ca/en/tools-hardware/...
# ...

# %% [markdown]
# ## LIGHTING

# %%
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/lighting/chandeliers.html?adlocation=LIT_Lighting_Chandeliers_en;',
                 'https://www.canadiantire.ca/en/lighting/pendant-lights.html?adlocation=LIT_Lighting_PendantLights_en;',
                 'https://www.canadiantire.ca/en/lighting/flush-semi-flush-mount-lights.html?adlocation=LIT_Lighting_FlushSemiFlushMountLights_en;',
                 'https://www.canadiantire.ca/en/lighting/track-canopy-lights.html?adlocation=LIT_Lighting_TrackLights_en;',
                 'https://www.canadiantire.ca/en/lighting/ceiling-fans-accessories.html?adlocation=LIT_Lighting_CeilingFansAccessories_en;',
                 'https://www.canadiantire.ca/en/lighting/floor-lamps.html?adlocation=LIT_Lighting_FloorLamps_en;',
                 'https://www.canadiantire.ca/en/lighting/table-lamps.html?adlocation=LIT_Lighting_TableLamps_en;',
                 'https://www.canadiantire.ca/en/lighting/desk-lamps.html?adlocation=LIT_Lighting_DeskLamps_en;',
                 'https://www.canadiantire.ca/en/lighting/wall-mount-lights.html?adlocation=LIT_Lighting_WallMountLights_en;',
                 'https://www.canadiantire.ca/en/lighting/bathroom-lights.html?adlocation=LIT_Lighting_BathroomLights_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-lighting/solar-lights.html?adlocation=LIT_Lighting_SolarLights_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-lighting/string-lights.html?adlocation=LIT_Lighting_StringLights_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-lighting/deck-fence-lights.html?adlocation=LIT_Lighting_DeckFenceLights_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-lighting/area-flood-lights.html?adlocation=LIT_Lighting_AreaFloodLighting_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-lighting/wall-entry-lighting.html?adlocation=LIT_Lighting_WallEntryLights_en;',
                 'https://www.canadiantire.ca/en/lighting/light-bulbs.html?adlocation=LIT_Lighting_LightBulbs_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/electrical/dimmers-switches-timers.html?adlocation=LIT_Lighting_DimmersSwitchesTimers_en;',                 
                 'https://www.canadiantire.ca/en/lighting/lighting-hardware/switch-wall-plates.html?adlocation=LIT_Lighting_WallPlates_en;',
                 'https://www.canadiantire.ca/en/lighting/fluorescent-light-fixtures.html?adlocation=LIT_Lighting_FlourescentLights_en;',
                 'https://www.canadiantire.ca/en/lighting/portable-work-lights.html?adlocation=LIT_Lighting_PortableWorkLights_en'
                ]

product_link_name = ['CHANDELIERS',
                     'PENDANT LIGHTS',
                     'FLUSHMOUNTS',
                     'TRACK LIGHTS',
                     'CEILING FANS',
                     'FLOOR LAMPS',
                     'TABLE LAMPS',
                     'DESK LAMPS',
                     'WALL MOUNT LIGHTS',
                     'BATHROOM LIGHTS',
                     'SOLAR LIGHTS',
                     'STRING LIGHTS',
                     'DECK FENCE LIGHTS',
                     'AREA FLOOD LIGHTS',
                     'WALL ENTRY LIGHTS',
                     'LIGHT BULBS',
                     'DIMMERS SWITCHES AND TIMERS',
                     'WALL PLATES',
                     'FLOURESCENT LIGHT FIXTURES',
                     'PORTABLE WORK LIGHTS'
        ]

### FILL THIS OUT######
product = "LIGHTING"
maj_name = "LIGHTING"
maj_link = "https://www.canadiantire.ca/en/lighting.html?"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#   product_name product_link_name  \
# 0     LIGHTING       CHANDELIERS
# 1     LIGHTING    PENDANT LIGHTS
# 2     LIGHTING       FLUSHMOUNTS
# 3     LIGHTING      TRACK LIGHTS
# 4     LIGHTING      CEILING FANS
#
#                                                 link major_category_name  \
# 0  https://www.canadiantire.ca/en/lighting/chande...            LIGHTING
# 1  https://www.canadiantire.ca/en/lighting/pendan...            LIGHTING
# 2  https://www.canadiantire.ca/en/lighting/flush-...            LIGHTING
# 3  https://www.canadiantire.ca/en/lighting/track-...            LIGHTING
# 4  https://www.canadiantire.ca/en/lighting/ceilin...            LIGHTING
#
#                              major_category_link
# 0  https://www.canadiantire.ca/en/lighting.html?
# 1  https://www.canadiantire.ca/en/lighting.html?
# 2  https://www.canadiantire.ca/en/lighting.html?
# 3  https://www.canadiantire.ca/en/lighting.html?
# 4  https://www.canadiantire.ca/en/lighting.html?

# %% [markdown]
# ## OUTDOOR POWER EQUIPMENT

# %%
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/outdoor-living/outdoor-power-equipment/lawn-mowers.html?adlocation=LIT_Category_Product_LawnMowers_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-power-equipment/hedge-trimmers.html?adlocation=LIT_Category_Product_HedgeTrimmersCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-power-equipment/tillers-cultivators.html?adlocation=LIT_Category_Product_TillersAndCultivatorsCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-power-equipment/grass-trimmers.html?adlocation=LIT_Category_Product_GrassTrimmers_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/generators-accessories.html?adlocation=LIT_Category_Product_GeneratorsAccessoriesCat_en;',
                 'https://www.canadiantire.ca/en/automotive/pressure-washers-parts-accessories.html?adlocation=LIT_Category_Product_PressureWashers_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-power-equipment/leaf-blowers.html?adlocation=LIT_Category_Product_LeafBlowersCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-power-equipment/chainsaws.html?adlocation=LIT_Category_Product_ChainsawsCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/outdoor-power-equipment/log-splitters-chippers-shredders.html?adlocation=LIT_Category_Product_LogSplittersChippersShreddersCat_en;',
                 'https://www.canadiantire.ca/en/outdoor-living/snow-removal/snowblowers.html?adlocation=LIT_Category_Product_Snowblowers_en;'
                ]

product_link_name = ['LAWN MOWERS',
                     'HEDGE TRIMMERS',
                     'TILLERS CULTIVATORS',
                     'GRASS TRIMMERS',
                     'GENERATOR ACCESSORIES',
                     'PRESSURE WASHERS',
                     'LEAF BLOWERS',
                     'CHAINSAWS',
                     'LOG SPLITTERS WOOD CHIPPERS AND SHREDDERS',
                     'SNOWBLOWERS'                     
        ]

### FILL THIS OUT######
product = "OUTDOOR_POWER_EQUIPMENT"
maj_name = "OUTDOOR POWER EQUIPMENT"
maj_link = "https://www.canadiantire.ca/en/outdoor-living/outdoor-power-equipment.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#               product_name      product_link_name  \
# 0  OUTDOOR_POWER_EQUIPMENT            LAWN MOWERS
# 1  OUTDOOR_POWER_EQUIPMENT         HEDGE TRIMMERS
# 2  OUTDOOR_POWER_EQUIPMENT    TILLERS CULTIVATORS
# 3  OUTDOOR_POWER_EQUIPMENT         GRASS TRIMMERS
# 4  OUTDOOR_POWER_EQUIPMENT  GENERATOR ACCESSORIES
#
#                                                 link      major_category_name  \
# 0  https://www.canadiantire.ca/en/outdoor-living/...  OUTDOOR POWER EQUIPMENT
# 1  https://www.canadiantire.ca/en/outdoor-living/...  OUTDOOR POWER EQUIPMENT
# 2  https://www.canadiantire.ca/en/outdoor-living/...  OUTDOOR POWER EQUIPMENT
# 3  https://www.canadiantire.ca/en/outdoor-living/...  OUTDOOR POWER EQUIPMENT
# 4  https://www.canadiantire.ca/en/tools-hardware/...  OUTDOOR POWER EQUIPMENT
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/outdoor-living/...
# 1  https://www.canadiantire.ca/en/outdoor-living/...
# ...

# %% [markdown]
# ## SMART HOME

# %%
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/household-pets/smart-home/lighting-switches-plugs.html?adlocation=LIT_Category_SmartLightingSwitchesPlugs_SmartHomeCLP_en;',
                 'https://www.canadiantire.ca/en/household-pets/smart-home/tracking-devices.html?adlocation=LIT_Category_SmartTrackingDevices_SmartHomeCLP_en;',
                 'https://www.canadiantire.ca/en/household-pets/smart-home/car-garage-accessories.html?adlocation=LIT_Category_SmartCarGarage_SmartHomeCLP_en;',
                 'https://www.canadiantire.ca/en/household-pets/smart-home/small-appliances.html?adlocation=LIT_Category_SmartSmallAppliances_SmartHomeCLP_en;',
                 'https://www.canadiantire.ca/en/household-pets/smart-home/hubs-voice-assistants-accessories.html?adlocation=LIT_Category_SmartHubsAssistantsAccessories_SmartHomeCLP_en;',
                 'https://www.canadiantire.ca/en/household-pets/smart-home/security-cameras.html?adlocation=LIT_Category_SmartSecurityCameras_SmartHomeCLP_en;',
                 'https://www.canadiantire.ca/en/household-pets/smart-home/doorbells.html?adlocation=LIT_Category_SmartDoorbells_SmartHomeCLP_en;',
                 'https://www.canadiantire.ca/en/household-pets/smart-home/locks-openers-accessories.html?adlocation=LIT_Category_SmartLocksOpenersAccessories_SmartHomeCLP_en;',
                 'https://www.canadiantire.ca/en/household-pets/smart-home/home-safety.html?adlocation=LIT_Category_SmartHomeSafety_SmartHomeCLP_en;',
                 'https://www.canadiantire.ca/en/household-pets/smart-home/thermostats-sensors.html?adlocation=LIT_Category_SmartThermostatsSensors_SmartHomeCLP_en;',
                 'https://www.canadiantire.ca/en/household-pets/smart-home/air-treatment.html?adlocation=LIT_Category_SmartAirTreatment_SmartHomeCLP_en;',
                 'https://www.canadiantire.ca/en/sports-rec/fitness-exercise/smart-fitness.html?adlocation=LIT_Category_SmartFitness_SmartHomeCLP_en;'
                ]

product_link_name = ['SMART LIGHTING, SWITCHES AND PLUGS',
                     'SMART TRACKING DEVICES',
                     'SMART CAR AND GARAGE',
                     'SMART SMALL APPLIANCES', 
                     'SMART HUBS VOICE ASSISTANTS AND ACCESSORIES',
                     'SMART SECURITY CAMERAS',
                     'SMART DOORBELLS', 
                     'SMART LOCKS OPENERS AND ACCESSORIES',
                     'SMART HOME SAFETY', 
                     'SMART THERMOSTATS AND SENSORS', 
                     'SMART AIR TREATMENT',
                     'SMART FITNESS'                  
        ]

### FILL THIS OUT######
product = "SMART_HOME"
maj_name = "SMART HOME"
maj_link = "https://www.canadiantire.ca/en/household-pets/smart-home.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#   product_name                            product_link_name  \
# 0   SMART_HOME           SMART LIGHTING, SWITCHES AND PLUGS
# 1   SMART_HOME                       SMART TRACKING DEVICES
# 2   SMART_HOME                         SMART CAR AND GARAGE
# 3   SMART_HOME                       SMART SMALL APPLIANCES
# 4   SMART_HOME  SMART HUBS VOICE ASSISTANTS AND ACCESSORIES
#
#                                                 link major_category_name  \
# 0  https://www.canadiantire.ca/en/household-pets/...          SMART HOME
# 1  https://www.canadiantire.ca/en/household-pets/...          SMART HOME
# 2  https://www.canadiantire.ca/en/household-pets/...          SMART HOME
# 3  https://www.canadiantire.ca/en/household-pets/...          SMART HOME
# 4  https://www.canadiantire.ca/en/household-pets/...          SMART HOME
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/household-pets/...
# 1  https://www.canadiantire.ca/en/household-pets/...
# ...

# %% [markdown]
# ## GENERATORS AND ACCESSORIES

# %%
import pandas as pd

# Creating lists of titles and links for Seat Covers
product_links = ['https://www.canadiantire.ca/en/tools-hardware/generators-accessories/generators.html?adlocation=LIT_Generators_GeneratorsAccessoriesCLP_en;',
                 'https://www.canadiantire.ca/en/tools-hardware/generators-accessories/generator-covers-accessories.html?adlocation=LIT_generatorscoversaccessories_GeneratorsAccessoriesCLP_en;',
                 'https://www.canadiantire.ca/en/heating-cooling/weatherstripping.html?'
                ]

product_link_name = ['ALL GENERATORS',
                     'GENERATOR COVERS',
                     'WEATHERSTRIPPING'
        ]

### FILL THIS OUT######
product = "GENERATORS_ACCESSORIES"
maj_name = "GENERATORS AND ACCESSORIES"
maj_link = "https://www.canadiantire.ca/en/tools-hardware/generators-accessories.html"
#######################

product_name = [product for i in range(len(product_links))]

prod = pd.DataFrame(data={'product_name': product_name, 'product_link_name': product_link_name, 'link': product_links})
prod['major_category_name'] = maj_name
prod['major_category_link'] = maj_link
prod.to_csv(f"files/{product}.csv", index=False)
prod.head()
# Out:
#              product_name product_link_name  \
# 0  GENERATORS_ACCESSORIES    ALL GENERATORS
# 1  GENERATORS_ACCESSORIES  GENERATOR COVERS
# 2  GENERATORS_ACCESSORIES  WEATHERSTRIPPING
#
#                                                 link  \
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# 2  https://www.canadiantire.ca/en/heating-cooling...
#
#           major_category_name  \
# 0  GENERATORS AND ACCESSORIES
# 1  GENERATORS AND ACCESSORIES
# 2  GENERATORS AND ACCESSORIES
#
#                                  major_category_link
# 0  https://www.canadiantire.ca/en/tools-hardware/...
# 1  https://www.canadiantire.ca/en/tools-hardware/...
# 2  https://www.canadiantire.ca/en/tools-hardware/...
