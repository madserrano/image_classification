# %% [markdown]
# ## **1. CONVOLUTIONAL NEURAL NETWORK (CNN) MODEL**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from keras.utils.np_utils import to_categorical
from tensorflow.keras.constraints import unit_norm
from tensorflow.python.keras import regularizers

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

import os
import cv2
import random
import time
import pickle

SEED = 0

def set_seeds(seed=SEED):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)
  
def set_global_determinism(seed=SEED):
    set_seeds(seed=seed)

    os.environ['TF_DETERMINISTIC_OPS'] = '1'
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
    
    tf.config.threading.set_inter_op_parallelism_threads(1)
    tf.config.threading.set_intra_op_parallelism_threads(1)

# Call the above function with seed value
set_global_determinism(seed=SEED)

# %%
# load Dataset

X = pickle.load(open("/content/drive/My Drive/Colab Notebooks/Capstone/testing/Outdoor_Living/X_Outdoor_Living.pickle", "rb"))
y = pickle.load(open("/content/drive/My Drive/Colab Notebooks/Capstone/testing/Outdoor_Living/y_Outdoor_Living.pickle", "rb"))
categories = pickle.load(open("/content/drive/My Drive/Colab Notebooks/Capstone/testing/Outdoor_Living/Outdoor_Living_categories.pickle", "rb"))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
num_classes = len(categories)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255.0
X_test /= 255.0
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (2660, 256, 256, 1)
# (2660, 38)
# (1140, 256, 256, 1)
# (1140, 38)

# %%
def print_graphs(model_history):
     # summarize history for loss
    plt.plot(model_history.history['loss'], color='orange')
    plt.plot(model_history.history['val_loss'], color='blue')
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['Training loss', 'Validation loss'], loc='upper left')
    plt.show()
    
    # summarize history for accuracy
    plt.plot(model_history.history['accuracy'], color='orange')
    plt.plot(model_history.history['val_accuracy'], color='blue')
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['Training accuracy', 'Validation accuracy'], loc='upper left')
    plt.show()

# %% [markdown]
# ## **1.2. MODEL 1**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', activation='relu'))
cnn.add(MaxPooling2D())

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu'))
cnn.add(MaxPooling2D())

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(num_classes, activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 64)      51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 262144)            0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              268436480
# _________________________________________________________________
# dense_1 (Dense)              (None, 38)                38950
# =================================================================
# Total params: 268,527,526
# Trainable params: 268,527,526
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 84/84 [==============================] - 44s 142ms/step - loss: 4.9878 - accuracy: 0.1451 - val_loss: 2.7988 - val_accuracy: 0.3053
# Epoch 2/10
# 84/84 [==============================] - 11s 135ms/step - loss: 1.7623 - accuracy: 0.5624 - val_loss: 1.7976 - val_accuracy: 0.5746
# Epoch 3/10
# 84/84 [==============================] - 11s 135ms/step - loss: 0.6595 - accuracy: 0.8417 - val_loss: 1.8784 - val_accuracy: 0.6325
# Epoch 4/10
# 84/84 [==============================] - 11s 136ms/step - loss: 0.3586 - accuracy: 0.9335 - val_loss: 1.5986 - val_accuracy: 0.6746
# Epoch 5/10
# 84/84 [==============================] - 11s 136ms/step - loss: 0.2051 - accuracy: 0.9583 - val_loss: 1.6061 - val_accuracy: 0.6754
# Epoch 6/10
# 84/84 [==============================] - 11s 137ms/step - loss: 0.1639 - accuracy: 0.9669 - val_loss: 1.7000 - val_accuracy: 0.6789
# Epoch 7/10
# 84/84 [==============================] - 12s 137ms/step - loss: 0.1272 - accuracy: 0.9699 - val_loss: 1.6439 - val_accuracy: 0.6632
# Epoch 8/10
# 84/84 [==============================] - 12s 138ms/step - loss: 0.1107 - accuracy: 0.9707 - val_loss: 1.5664 - val_accuracy: 0.6860
# Epoch 9/10
# 84/84 [==============================] - 12s 138ms/step - loss: 0.1031 - accuracy: 0.9752 - val_loss: 1.5987 - val_accuracy: 0.6711
# Epoch 10/10
# 84/84 [==============================] - 11s 137ms/step - loss: 0.0948 - accuracy: 0.9707 - val_loss: 1.4543 - val_accuracy: 0.6868
# Time elapsed: 146.8262333869934s

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **1.3. MODEL 2**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', activation='relu'))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu'))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(num_classes, activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

import time
start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 256, 256, 32)      832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 64)      51264
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 262144)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              268436480
# _________________________________________________________________
# dense_3 (Dense)              (None, 38)                38950
# =================================================================
# Total params: 268,527,526
# Trainable params: 268,527,526
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 84/84 [==============================] - 13s 145ms/step - loss: 5.1164 - accuracy: 0.0278 - val_loss: 3.6382 - val_accuracy: 0.0211
# Epoch 2/10
# 84/84 [==============================] - 12s 144ms/step - loss: 3.5246 - accuracy: 0.0846 - val_loss: 3.1259 - val_accuracy: 0.2474
# Epoch 3/10
# 84/84 [==============================] - 12s 144ms/step - loss: 2.2633 - accuracy: 0.4669 - val_loss: 2.1088 - val_accuracy: 0.5167
# Epoch 4/10
# 84/84 [==============================] - 12s 144ms/step - loss: 1.0536 - accuracy: 0.7195 - val_loss: 1.9120 - val_accuracy: 0.6114
# Epoch 5/10
# 84/84 [==============================] - 12s 144ms/step - loss: 0.5568 - accuracy: 0.8568 - val_loss: 1.9091 - val_accuracy: 0.6500
# Epoch 6/10
# 84/84 [==============================] - 12s 145ms/step - loss: 0.3676 - accuracy: 0.9222 - val_loss: 2.0454 - val_accuracy: 0.6561
# Epoch 7/10
# 84/84 [==============================] - 12s 145ms/step - loss: 0.2572 - accuracy: 0.9432 - val_loss: 1.9128 - val_accuracy: 0.6649
# Epoch 8/10
# 84/84 [==============================] - 12s 145ms/step - loss: 0.2050 - accuracy: 0.9523 - val_loss: 1.8406 - val_accuracy: 0.6711
# Epoch 9/10
# 84/84 [==============================] - 12s 144ms/step - loss: 0.1653 - accuracy: 0.9617 - val_loss: 1.8675 - val_accuracy: 0.6737
# Epoch 10/10
# 84/84 [==============================] - 12s 144ms/step - loss: 0.1479 - accuracy: 0.9673 - val_loss: 1.7831 - val_accuracy: 0.6684
# Time elapsed: 121.67967963218689s

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **1.4. MODEL 3**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', kernel_initializer='he_normal', activation='relu'))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(num_classes, activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 256, 256, 32)      832
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 128, 64)      51264
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 262144)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              268436480
# _________________________________________________________________
# dense_5 (Dense)              (None, 38)                38950
# =================================================================
# Total params: 268,527,526
# Trainable params: 268,527,526
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 84/84 [==============================] - 13s 145ms/step - loss: 18.0701 - accuracy: 0.0263 - val_loss: 4.0506 - val_accuracy: 0.0211
# Epoch 2/10
# 84/84 [==============================] - 12s 144ms/step - loss: 3.8330 - accuracy: 0.1293 - val_loss: 3.1903 - val_accuracy: 0.3544
# Epoch 3/10
# 84/84 [==============================] - 12s 144ms/step - loss: 2.3190 - accuracy: 0.5545 - val_loss: 2.4019 - val_accuracy: 0.5553
# Epoch 4/10
# 84/84 [==============================] - 12s 144ms/step - loss: 1.1911 - accuracy: 0.7977 - val_loss: 2.2836 - val_accuracy: 0.6193
# Epoch 5/10
# 84/84 [==============================] - 12s 144ms/step - loss: 0.7859 - accuracy: 0.8944 - val_loss: 2.3737 - val_accuracy: 0.6439
# Epoch 6/10
# 84/84 [==============================] - 12s 144ms/step - loss: 0.6666 - accuracy: 0.9286 - val_loss: 2.2136 - val_accuracy: 0.6596
# Epoch 7/10
# 84/84 [==============================] - 12s 145ms/step - loss: 0.5526 - accuracy: 0.9485 - val_loss: 2.0926 - val_accuracy: 0.6658
# Epoch 8/10
# 84/84 [==============================] - 12s 145ms/step - loss: 0.4582 - accuracy: 0.9624 - val_loss: 2.1245 - val_accuracy: 0.6693
# Epoch 9/10
# 84/84 [==============================] - 12s 144ms/step - loss: 0.4340 - accuracy: 0.9602 - val_loss: 2.3045 - val_accuracy: 0.6667
# Epoch 10/10
# 84/84 [==============================] - 12s 144ms/step - loss: 0.4065 - accuracy: 0.9662 - val_loss: 2.0827 - val_accuracy: 0.6684
# Time elapsed: 121.66220116615295s

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **1.5. MODEL 4**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', kernel_initializer='he_normal', activation='relu', kernel_constraint=unit_norm()))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(num_classes, activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())


start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 256, 256, 32)      832
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 128, 128, 64)      51264
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 262144)            0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              268436480
# _________________________________________________________________
# dense_7 (Dense)              (None, 38)                38950
# =================================================================
# Total params: 268,527,526
# Trainable params: 268,527,526
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-13-741e25934c42> in <module>()
#      18
#      19 start = time.time()
# ---> 20 history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
#      21 end = time.time()
#      22 print('Time elapsed: {}s'.format(end-start))
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     948         # Lifting succeeded, so variables are initialized and we can run the
#     949         # stateless function.
# --> 950         return self._stateless_fn(*args, **kwds)
#     951     else:
#     952       _, _, _, filtered_flat_args = \
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3023     return graph_function._call_flat(
# -> 3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#    3026   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1959       # No tape is watching; skip to running the function.
#    1960       return self._build_call_outputs(self._inference_function.call(
# -> 1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#    1963         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[262144,1024] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node gradient_tape/sequential_3/dense_6/MatMul_1 (defined at <ipython-input-13-741e25934c42>:20) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_train_function_11712]
#
# Function call stack:
# train_function

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **1.6. MODEL 5**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', kernel_initializer='he_normal', activation='relu', kernel_constraint=unit_norm()))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(num_classes, activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

import time
start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **1.7. MODEL 6**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', kernel_initializer='he_normal', activation='relu', kernel_constraint=unit_norm()))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.05))

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.5))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(len(categories), activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

import time
start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **1.8. MODEL 7**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(3,3), input_shape=X.shape[1:], padding='same', kernel_initializer='he_normal', activation='relu', kernel_constraint=unit_norm()))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Conv2D(64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(len(categories), activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

import time
start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 262144)            0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              268436480
# _________________________________________________________________
# dense_1 (Dense)              (None, 38)                38950
# =================================================================
# Total params: 268,494,246
# Trainable params: 268,494,246
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 84/84 [==============================] - 15s 141ms/step - loss: 38.6612 - accuracy: 0.0308 - val_loss: 4.0173 - val_accuracy: 0.0237
# Epoch 2/10
# 84/84 [==============================] - 11s 135ms/step - loss: 3.9949 - accuracy: 0.0444 - val_loss: 3.9765 - val_accuracy: 0.0219
# Epoch 3/10
# 84/84 [==============================] - 11s 135ms/step - loss: 3.6803 - accuracy: 0.1553 - val_loss: 3.2118 - val_accuracy: 0.3149
# Epoch 4/10
# 84/84 [==============================] - 11s 134ms/step - loss: 2.2585 - accuracy: 0.5147 - val_loss: 2.8004 - val_accuracy: 0.4658
# Epoch 5/10
# 84/84 [==============================] - 11s 133ms/step - loss: 1.3351 - accuracy: 0.7455 - val_loss: 2.5508 - val_accuracy: 0.5570
# Epoch 6/10
# 84/84 [==============================] - 11s 132ms/step - loss: 0.9473 - accuracy: 0.8376 - val_loss: 2.6051 - val_accuracy: 0.5982
# Epoch 7/10
# 84/84 [==============================] - 11s 133ms/step - loss: 0.7531 - accuracy: 0.8797 - val_loss: 2.4561 - val_accuracy: 0.6219
# Epoch 8/10
# 84/84 [==============================] - 11s 134ms/step - loss: 0.5996 - accuracy: 0.9143 - val_loss: 2.4760 - val_accuracy: 0.6316
# Epoch 9/10
# 84/84 [==============================] - 11s 133ms/step - loss: 0.5533 - accuracy: 0.9323 - val_loss: 2.4261 - val_accuracy: 0.6254
# Epoch 10/10
# 84/84 [==============================] - 11s 133ms/step - loss: 0.4815 - accuracy: 0.9462 - val_loss: 2.3593 - val_accuracy: 0.6509
# Time elapsed: 115.8223865032196s

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **Saving model 7**

# %%
# cnn.save('/content/drive/My Drive/Colab Notebooks/Capstone/testing/outdoor_living.h5')

cnn_keras_file = '/content/drive/My Drive/Colab Notebooks/Capstone/testing/outdoor_living.h5'
print("Saving cnn model to: ", cnn_keras_file)
tf.keras.models.save_model(cnn, cnn_keras_file, include_optimizer=False)
# Out:
# Saving cnn model to:  /content/drive/My Drive/Colab Notebooks/Capstone/testing/outdoor_living.h5
